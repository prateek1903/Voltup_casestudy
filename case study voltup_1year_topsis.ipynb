# %% [markdown]
# ## Libraries and model characterstics

# %%
from pulp import *
import numpy as np, pandas as pd
import warnings
warnings.filterwarnings('always')
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt

# %%
number_of_manufacturing_center = 1
number_of_distribution_center = 1
number_of_swapping_station = 15

# %% [markdown]
# ## Variables and data

# %%
for i in range(number_of_distribution_center):
    if i ==0:
        Xb0_c = LpVariable.dicts("Xb0_c",range(number_of_swapping_station),lowBound=0,cat='Integer')

# %%
for i in range(number_of_distribution_center):
    if i ==0:
        Xcb0 = LpVariable.dicts("Xb0_rev_c",range(number_of_swapping_station),lowBound=0,cat='Integer')

# %%
Yb = LpVariable.dicts("Yb",range(number_of_distribution_center),lowBound=0,upBound=1,cat='Integer')
Yb
# Out:
# {0: Yb_0}

# %%
Yc = LpVariable.dicts('Yc',range(number_of_swapping_station),lowBound=0,upBound=1,cat='Integer')
Yc
# Out:
# {0: Yc_0,
#  1: Yc_1,
#  2: Yc_2,
#  3: Yc_3,
#  4: Yc_4,
#  5: Yc_5,
#  6: Yc_6,
#  7: Yc_7,
#  8: Yc_8,
#  9: Yc_9,
#  10: Yc_10,
#  11: Yc_11,
#  12: Yc_12,
#  13: Yc_13,
#  14: Yc_14}

# %%
distance_BC = pd.read_excel(r'D:\Project\Case Study Values.xlsx',sheet_name='dist_B_to_C')
distance_BC
# Out:
#       flow  dist                Name
# 0    Xb1c1     8       Shastri Nagar
# 1    Xb1c2     9            Jhotwara
# 2    Xb1c3    13            Chandpol
# 3    Xb1c4    14           modikhana
# 4    Xb1c5    16           Ghat gate
# 5    Xb1c6    16  Laxmi Narayan Puri
# 6    Xb1c7    15       Subhash Chowk
# 7    Xb1c8    23                Amer
# 8    Xb1c9    15          Brahmapuri
# 9   Xb1c10    22       Malviya Nagar
# 10  Xb1c11    21          Mansarovar
# 11  Xb1c12    26            Sanganer
# 12  Xb1c13    16            Surajpol
# 13  Xb1c14    12         Sindhi Camp
# 14  Xb1c15    18           Raja park

# %%
constants = pd.read_excel(r'D:\Project\Case Study Values.xlsx',sheet_name='Constants')
constants
# Out:
#            const    value
# 0            Cab    12.00
# 1            Vab   100.00
# 2            Cbc    20.00
# 3            Vbc    20.00
# 4          alpha     0.02
# 5  Charging Cost    27.00
# 6            Zab   220.00
# 7            Zbc   120.00
# 8             Zo  2850.00

# %%
coef_for_B = pd.read_excel(r'D:\Project\Case Study Values.xlsx',sheet_name='Coef for B')
coef_for_B
# Out:
#   Unnamed: 0      Acq  Disposal Cost  Rent + Labour 1  Rent + Labour 3  \
# 0        Yb1  1000000            400          4500000         13500000
#
#    Capacity
# 0     18000

# %%
coef_for_C= pd.read_excel(r'D:\Project\Case Study Values.xlsx',sheet_name='Coef for C')
coef_for_C
# Out:
#                   Name Swapping station  Acquition cost  Rent + Labour 1  \
# 0        Shastri Nagar              Yc1          850000           240000
# 1             Jhotwara              Yc2          475000            96000
# 2             Chandpol              Yc3          850000           324000
# 3            modikhana              Yc4          850000           144000
# 4            Ghat gate              Yc5          475000            96000
# 5   Laxmi Narayan Puri              Yc6          850000           288000
# 6        Subhash Chowk              Yc7          850000           384000
# 7                 Amer              Yc8          475000           180000
# 8           Brahmapuri              Yc9          850000           264000
# 9        Malviya Nagar             Yc10          475000           324000
# 10          Mansarovar             yc11          850000           288000
# 11            Sanganer             yc12          475000           120000
# 12            Surajpol             yc13          475000            96000
# 13         Sindhi Camp             yc14          850000           384000
# 14           Raja park             yc15          475000           324000
#
#     Rent + Labour 3  Demand1  Demand3  Capacity
# 0            720000    18000    59580        50
# 1            288000    10000    33100        30
# 2            972000    16000    52960        50
# 3            432000    18000    59580        50
# 4            288000    11000    36410        30
# 5            864000    17000    56270        50
# 6           1152000    20000    66200       100
# 7            540000     9000    29790        30
# 8            792000    13000    43030        50
# 9            972000    11000    36410        30
# 10           864000    12000    39720        50
# 11           360000    16000    52960        30
# 12           288000    18000    59580        30
# 13          1152000    13000    43030        50
# 14           972000     7000    23170        30

# %% [markdown]
# ## objective 1:cost

# %% [markdown]
# ### Transportation cost straight flow

# %%
Xbc = {0:Xb0_c}

# %%
k = constants.iloc[2,1]/constants.iloc[3,1]
list_of_transportation_cost_st=[]
for m in range(number_of_distribution_center):
    list_of_transportation_cost_st.append([distance_BC.iloc[i,1]*Xbc[m][i]*k for i in range(number_of_swapping_station)])

# %%
print(list_of_transportation_cost_st)
# Out:
# [[8.0*Xb0_c_0 + 0.0, 9.0*Xb0_c_1 + 0.0, 13.0*Xb0_c_2 + 0.0, 14.0*Xb0_c_3 + 0.0, 16.0*Xb0_c_4 + 0.0, 16.0*Xb0_c_5 + 0.0, 15.0*Xb0_c_6 + 0.0, 23.0*Xb0_c_7 + 0.0, 15.0*Xb0_c_8 + 0.0, 22.0*Xb0_c_9 + 0.0, 21.0*Xb0_c_10 + 0.0, 26.0*Xb0_c_11 + 0.0, 16.0*Xb0_c_12 + 0.0, 12.0*Xb0_c_13 + 0.0, 18.0*Xb0_c_14 + 0.0]]

# %% [markdown]
# ### Transportation cost reverse flow

# %%
Xcb = {0:Xcb0
      }

# %%
k = constants.iloc[2,1]/constants.iloc[3,1]
list_of_transportation_cost_rev=[]
for m in range(number_of_distribution_center):
    list_of_transportation_cost_rev.append([distance_BC.iloc[i,1]*Xcb[m][i]*k for i in range(number_of_swapping_station)])

# %%
list_of_transportation_cost_rev
# Out:
# [[8.0*Xb0_rev_c_0 + 0.0,
#   9.0*Xb0_rev_c_1 + 0.0,
#   13.0*Xb0_rev_c_2 + 0.0,
#   14.0*Xb0_rev_c_3 + 0.0,
#   16.0*Xb0_rev_c_4 + 0.0,
#   16.0*Xb0_rev_c_5 + 0.0,
#   15.0*Xb0_rev_c_6 + 0.0,
#   23.0*Xb0_rev_c_7 + 0.0,
#   15.0*Xb0_rev_c_8 + 0.0,
#   22.0*Xb0_rev_c_9 + 0.0,
#   21.0*Xb0_rev_c_10 + 0.0,
#   26.0*Xb0_rev_c_11 + 0.0,
#   16.0*Xb0_rev_c_12 + 0.0,
#   12.0*Xb0_rev_c_13 + 0.0,
#   18.0*Xb0_rev_c_14 + 0.0]]

# %% [markdown]
# ### Disposal cost

# %%
Xbd = LpVariable.dicts('Xdb',range(number_of_distribution_center),lowBound=0,cat='Integer')
Xbd
# Out:
# {0: Xdb_0}

# %%
#coef_for_B = pd.read_excel(r'D:\Project\values for 10.xlsx',sheet_name='Coef for B')
coef_for_B
# Out:
#   Unnamed: 0      Acq  Disposal Cost  Rent + Labour 1  Rent + Labour 3  \
# 0        Yb1  1000000            400          4500000         13500000
#
#    Capacity
# 0     18000

# %%
list_of_disposal_cost = [coef_for_B.iloc[i,2]*Xbd[i] for i in range(number_of_distribution_center)]
list_of_disposal_cost
# Out:
# [400*Xdb_0 + 0]

# %% [markdown]
# ### Rent + labour

# %% [markdown]
# #### rent labor of distribution center

# %%
rent_labour_of_distribution_center_1 = [coef_for_B.iloc[i,3]*Yb[i] for i in range(number_of_distribution_center)]
rent_labour_of_distribution_center_1
# Out:
# [4500000*Yb_0 + 0]

# %%
rent_labour_of_distribution_center_3 = [coef_for_B.iloc[i,4]*Yb[i] for i in range(number_of_distribution_center)]
rent_labour_of_distribution_center_3
# Out:
# [13500000*Yb_0 + 0]

# %% [markdown]
# #### rent labour of swapping station

# %%
coef_for_C
# Out:
#                   Name Swapping station  Acquition cost  Rent + Labour 1  \
# 0        Shastri Nagar              Yc1          850000           240000
# 1             Jhotwara              Yc2          475000            96000
# 2             Chandpol              Yc3          850000           324000
# 3            modikhana              Yc4          850000           144000
# 4            Ghat gate              Yc5          475000            96000
# 5   Laxmi Narayan Puri              Yc6          850000           288000
# 6        Subhash Chowk              Yc7          850000           384000
# 7                 Amer              Yc8          475000           180000
# 8           Brahmapuri              Yc9          850000           264000
# 9        Malviya Nagar             Yc10          475000           324000
# 10          Mansarovar             yc11          850000           288000
# 11            Sanganer             yc12          475000           120000
# 12            Surajpol             yc13          475000            96000
# 13         Sindhi Camp             yc14          850000           384000
# 14           Raja park             yc15          475000           324000
#
#     Rent + Labour 3  Demand1  Demand3  Capacity
# 0            720000    18000    59580        50
# 1            288000    10000    33100        30
# 2            972000    16000    52960        50
# 3            432000    18000    59580        50
# 4            288000    11000    36410        30
# 5            864000    17000    56270        50
# 6           1152000    20000    66200       100
# 7            540000     9000    29790        30
# 8            792000    13000    43030        50
# 9            972000    11000    36410        30
# 10           864000    12000    39720        50
# 11           360000    16000    52960        30
# 12           288000    18000    59580        30
# 13          1152000    13000    43030        50
# 14           972000     7000    23170        30

# %%
rent_labour_of_swapping_station_1 = [coef_for_C.iloc[i,3]*Yc[i] for i in range(number_of_swapping_station)]
rent_labour_of_swapping_station_1
# Out:
# [240000*Yc_0 + 0,
#  96000*Yc_1 + 0,
#  324000*Yc_2 + 0,
#  144000*Yc_3 + 0,
#  96000*Yc_4 + 0,
#  288000*Yc_5 + 0,
#  384000*Yc_6 + 0,
#  180000*Yc_7 + 0,
#  264000*Yc_8 + 0,
#  324000*Yc_9 + 0,
#  288000*Yc_10 + 0,
#  120000*Yc_11 + 0,
#  96000*Yc_12 + 0,
#  384000*Yc_13 + 0,
#  324000*Yc_14 + 0]

# %%
rent_labour_of_swapping_station_3 = [coef_for_C.iloc[i,4]*Yc[i] for i in range(number_of_swapping_station)]
rent_labour_of_swapping_station_3
# Out:
# [720000*Yc_0 + 0,
#  288000*Yc_1 + 0,
#  972000*Yc_2 + 0,
#  432000*Yc_3 + 0,
#  288000*Yc_4 + 0,
#  864000*Yc_5 + 0,
#  1152000*Yc_6 + 0,
#  540000*Yc_7 + 0,
#  792000*Yc_8 + 0,
#  972000*Yc_9 + 0,
#  864000*Yc_10 + 0,
#  360000*Yc_11 + 0,
#  288000*Yc_12 + 0,
#  1152000*Yc_13 + 0,
#  972000*Yc_14 + 0]

# %% [markdown]
# ### charging cost

# %%
list_of_charging_cost_1 = [constants.iloc[5,1]*coef_for_C.iloc[i,5]*Yc[i] for i in range(number_of_swapping_station)]
list_of_charging_cost_1
# Out:
# [486000.0*Yc_0 + 0.0,
#  270000.0*Yc_1 + 0.0,
#  432000.0*Yc_2 + 0.0,
#  486000.0*Yc_3 + 0.0,
#  297000.0*Yc_4 + 0.0,
#  459000.0*Yc_5 + 0.0,
#  540000.0*Yc_6 + 0.0,
#  243000.0*Yc_7 + 0.0,
#  351000.0*Yc_8 + 0.0,
#  297000.0*Yc_9 + 0.0,
#  324000.0*Yc_10 + 0.0,
#  432000.0*Yc_11 + 0.0,
#  486000.0*Yc_12 + 0.0,
#  351000.0*Yc_13 + 0.0,
#  189000.0*Yc_14 + 0.0]

# %%
list_of_charging_cost_3 = [constants.iloc[5,1]*coef_for_C.iloc[i,6]*Yc[i] for i in range(number_of_swapping_station)]
list_of_charging_cost_3
# Out:
# [1608660.0*Yc_0 + 0.0,
#  893700.0*Yc_1 + 0.0,
#  1429920.0*Yc_2 + 0.0,
#  1608660.0*Yc_3 + 0.0,
#  983070.0*Yc_4 + 0.0,
#  1519290.0*Yc_5 + 0.0,
#  1787400.0*Yc_6 + 0.0,
#  804330.0*Yc_7 + 0.0,
#  1161810.0*Yc_8 + 0.0,
#  983070.0*Yc_9 + 0.0,
#  1072440.0*Yc_10 + 0.0,
#  1429920.0*Yc_11 + 0.0,
#  1608660.0*Yc_12 + 0.0,
#  1161810.0*Yc_13 + 0.0,
#  625590.0*Yc_14 + 0.0]

# %% [markdown]
# ### Transportation cost A to B

# %%
num_of_Xab = number_of_manufacturing_center*number_of_distribution_center
Xab = LpVariable.dicts('Xab',range(num_of_Xab),lowBound=0,cat='Integer')
Xab
# Out:
# {0: Xab_0}

# %%
dist_A_to_B = pd.read_excel(r'D:\Project\Case Study Values.xlsx',sheet_name='dist_A_to_B')
dist_A_to_B
# Out:
#     flow  dist
# 0  Xa1b1   222

# %%
m = constants.iloc[0,1]/constants.iloc[1,1]
list_of_transportation_A_to_B = [dist_A_to_B.iloc[i,1]*Xab[i]*m for i in range(num_of_Xab)]
list_of_transportation_A_to_B
# Out:
# [26.64*Xab_0 + 0.0]

# %% [markdown]
# ### Acquisition cost of distribution center

# %%
#Yb = LpVariable.dicts("Yb",range(number_of_distribution_center),lowBound=0,upBound=1,cat='Integer')
Yb
# Out:
# {0: Yb_0}

# %%
coef_for_B
# Out:
#   Unnamed: 0      Acq  Disposal Cost  Rent + Labour 1  Rent + Labour 3  \
# 0        Yb1  1000000            400          4500000         13500000
#
#    Capacity
# 0     18000

# %%
list_of_acq_cost_distribution = [coef_for_B.iloc[i,1]*Yb[i] for i in range(number_of_distribution_center)]
list_of_acq_cost_distribution
# Out:
# [1000000*Yb_0 + 0]

# %% [markdown]
# ### Acquisition cost of swapping center

# %%
#coef_for_C= pd.read_excel(r'D:\Project\values for 10.xlsx',sheet_name='Coef for C')
coef_for_C
# Out:
#                   Name Swapping station  Acquition cost  Rent + Labour 1  \
# 0        Shastri Nagar              Yc1          850000           240000
# 1             Jhotwara              Yc2          475000            96000
# 2             Chandpol              Yc3          850000           324000
# 3            modikhana              Yc4          850000           144000
# 4            Ghat gate              Yc5          475000            96000
# 5   Laxmi Narayan Puri              Yc6          850000           288000
# 6        Subhash Chowk              Yc7          850000           384000
# 7                 Amer              Yc8          475000           180000
# 8           Brahmapuri              Yc9          850000           264000
# 9        Malviya Nagar             Yc10          475000           324000
# 10          Mansarovar             yc11          850000           288000
# 11            Sanganer             yc12          475000           120000
# 12            Surajpol             yc13          475000            96000
# 13         Sindhi Camp             yc14          850000           384000
# 14           Raja park             yc15          475000           324000
#
#     Rent + Labour 3  Demand1  Demand3  Capacity
# 0            720000    18000    59580        50
# 1            288000    10000    33100        30
# 2            972000    16000    52960        50
# 3            432000    18000    59580        50
# 4            288000    11000    36410        30
# 5            864000    17000    56270        50
# 6           1152000    20000    66200       100
# 7            540000     9000    29790        30
# 8            792000    13000    43030        50
# 9            972000    11000    36410        30
# 10           864000    12000    39720        50
# 11           360000    16000    52960        30
# 12           288000    18000    59580        30
# 13          1152000    13000    43030        50
# 14           972000     7000    23170        30

# %%
list_of_acq_swap = [coef_for_C.iloc[i,2]*Yc[i] for i in range(number_of_swapping_station)]
list_of_acq_swap
# Out:
# [850000*Yc_0 + 0,
#  475000*Yc_1 + 0,
#  850000*Yc_2 + 0,
#  850000*Yc_3 + 0,
#  475000*Yc_4 + 0,
#  850000*Yc_5 + 0,
#  850000*Yc_6 + 0,
#  475000*Yc_7 + 0,
#  850000*Yc_8 + 0,
#  475000*Yc_9 + 0,
#  850000*Yc_10 + 0,
#  475000*Yc_11 + 0,
#  475000*Yc_12 + 0,
#  850000*Yc_13 + 0,
#  475000*Yc_14 + 0]

# %% [markdown]
# ### objective function

# %%
prob = LpProblem('Cost',LpMinimize)
prob +=lpSum(list_of_transportation_cost_rev+list_of_transportation_cost_st+list_of_acq_cost_distribution+list_of_disposal_cost+list_of_transportation_A_to_B+list_of_charging_cost_1+rent_labour_of_distribution_center_1+rent_labour_of_swapping_station_1)

# %%
prob
# Out:
# Cost:
# MINIMIZE
# 26.64*Xab_0 + 8.0*Xb0_c_0 + 9.0*Xb0_c_1 + 21.0*Xb0_c_10 + 26.0*Xb0_c_11 + 16.0*Xb0_c_12 + 12.0*Xb0_c_13 + 18.0*Xb0_c_14 + 13.0*Xb0_c_2 + 14.0*Xb0_c_3 + 16.0*Xb0_c_4 + 16.0*Xb0_c_5 + 15.0*Xb0_c_6 + 23.0*Xb0_c_7 + 15.0*Xb0_c_8 + 22.0*Xb0_c_9 + 8.0*Xb0_rev_c_0 + 9.0*Xb0_rev_c_1 + 21.0*Xb0_rev_c_10 + 26.0*Xb0_rev_c_11 + 16.0*Xb0_rev_c_12 + 12.0*Xb0_rev_c_13 + 18.0*Xb0_rev_c_14 + 13.0*Xb0_rev_c_2 + 14.0*Xb0_rev_c_3 + 16.0*Xb0_rev_c_4 + 16.0*Xb0_rev_c_5 + 15.0*Xb0_rev_c_6 + 23.0*Xb0_rev_c_7 + 15.0*Xb0_rev_c_8 + 22.0*Xb0_rev_c_9 + 400*Xdb_0 + 5500000*Yb_0 + 726000.0*Yc_0 + 366000.0*Yc_1 + 612000.0*Yc_10 + 552000.0*Yc_11 + 582000.0*Yc_12 + 735000.0*Yc_13 + 513000.0*Yc_14 + 756000.0*Yc_2 + 630000.0*Yc_3 + 393000.0*Yc_4 + 747000.0*Yc_5 + 924000.0*Yc_6 + 423000.0*Yc_7 + 615000.0*Yc_8 + 621000.0*Yc_9 + 0.0
# VARIABLES
# 0 <= Xab_0 Integer
# 0 <= Xb0_c_0 Integer
# 0 <= Xb0_c_1 Integer
# 0 <= Xb0_c_10 Integer
# 0 <= Xb0_c_11 Integer
# 0 <= Xb0_c_12 Integer
# 0 <= Xb0_c_13 Integer
# 0 <= Xb0_c_14 Integer
# 0 <= Xb0_c_2 Integer
# 0 <= Xb0_c_3 Integer
# 0 <= Xb0_c_4 Integer
# 0 <= Xb0_c_5 Integer
# 0 <= Xb0_c_6 Integer
# 0 <= Xb0_c_7 Integer
# 0 <= Xb0_c_8 Integer
# 0 <= Xb0_c_9 Integer
# 0 <= Xb0_rev_c_0 Integer
# 0 <= Xb0_rev_c_1 Integer
# 0 <= Xb0_rev_c_10 Integer
# 0 <= Xb0_rev_c_11 Integer
# 0 <= Xb0_rev_c_12 Integer
# 0 <= Xb0_rev_c_13 Integer
# 0 <= Xb0_rev_c_14 Integer
# 0 <= Xb0_rev_c_2 Integer
# 0 <= Xb0_rev_c_3 Integer
# 0 <= Xb0_rev_c_4 Integer
# 0 <= Xb0_rev_c_5 Integer
# 0 <= Xb0_rev_c_6 Integer
# 0 <= Xb0_rev_c_7 Integer
# 0 <= Xb0_rev_c_8 Integer
# 0 <= Xb0_rev_c_9 Integer
# 0 <= Xdb_0 Integer
# 0 <= Yb_0 <= 1 Integer
# 0 <= Yc_0 <= 1 Integer
# 0 <= Yc_1 <= 1 Integer
# 0 <= Yc_10 <= 1 Integer
# 0 <= Yc_11 <= 1 Integer
# 0 <= Yc_12 <= 1 Integer
# 0 <= Yc_13 <= 1 Integer
# 0 <= Yc_14 <= 1 Integer
# 0 <= Yc_2 <= 1 Integer
# 0 <= Yc_3 <= 1 Integer
# 0 <= Yc_4 <= 1 Integer
# 0 <= Yc_5 <= 1 Integer
# 0 <= Yc_6 <= 1 Integer
# 0 <= Yc_7 <= 1 Integer
# 0 <= Yc_8 <= 1 Integer
# 0 <= Yc_9 <= 1 Integer

# %% [markdown]
# ## constraints

# %% [markdown]
# ### Disposal constraint at swapping station

# %%
coef_for_C
# Out:
#                   Name Swapping station  Acquition cost  Rent + Labour 1  \
# 0        Shastri Nagar              Yc1          850000           240000
# 1             Jhotwara              Yc2          475000            96000
# 2             Chandpol              Yc3          850000           324000
# 3            modikhana              Yc4          850000           144000
# 4            Ghat gate              Yc5          475000            96000
# 5   Laxmi Narayan Puri              Yc6          850000           288000
# 6        Subhash Chowk              Yc7          850000           384000
# 7                 Amer              Yc8          475000           180000
# 8           Brahmapuri              Yc9          850000           264000
# 9        Malviya Nagar             Yc10          475000           324000
# 10          Mansarovar             yc11          850000           288000
# 11            Sanganer             yc12          475000           120000
# 12            Surajpol             yc13          475000            96000
# 13         Sindhi Camp             yc14          850000           384000
# 14           Raja park             yc15          475000           324000
#
#     Rent + Labour 3  Demand1  Demand3  Capacity
# 0            720000    18000    59580        50
# 1            288000    10000    33100        30
# 2            972000    16000    52960        50
# 3            432000    18000    59580        50
# 4            288000    11000    36410        30
# 5            864000    17000    56270        50
# 6           1152000    20000    66200       100
# 7            540000     9000    29790        30
# 8            792000    13000    43030        50
# 9            972000    11000    36410        30
# 10           864000    12000    39720        50
# 11           360000    16000    52960        30
# 12           288000    18000    59580        30
# 13          1152000    13000    43030        50
# 14           972000     7000    23170        30

# %%
Xcb
# Out:
# {0: {0: Xb0_rev_c_0,
#   1: Xb0_rev_c_1,
#   2: Xb0_rev_c_2,
#   3: Xb0_rev_c_3,
#   4: Xb0_rev_c_4,
#   5: Xb0_rev_c_5,
#   6: Xb0_rev_c_6,
#   7: Xb0_rev_c_7,
#   8: Xb0_rev_c_8,
#   9: Xb0_rev_c_9,
#   10: Xb0_rev_c_10,
#   11: Xb0_rev_c_11,
#   12: Xb0_rev_c_12,
#   13: Xb0_rev_c_13,
#   14: Xb0_rev_c_14}}

# %% [markdown]
# #### disposal constraint for 1 year

# %%
for i in range(number_of_swapping_station):
    prob += lpSum(Xcb[j][i] for j in range(number_of_distribution_center))>=coef_for_C.iloc[i,5]*Yc[i]*0.02

# %% [markdown]
# #### disposal constraint for 3 year

# %%
#for i in range(number_of_swapping_station):
 #   prob += lpSum(Xcb[j][i] for j in range(number_of_distribution_center))>=coef_for_C.iloc[i,6]*Yc[i]*0.02

# %% [markdown]
# ### binary constraint

# %%
for i in range(number_of_distribution_center):
    for j in range(number_of_swapping_station):
        prob += Yb[i]>=Xbc[i][j]*0.00002
        prob += Yb[i]>=Xcb[i][j]*0.00002

# %% [markdown]
# ### Disposal constraint

# %%
constants
# Out:
#            const    value
# 0            Cab    12.00
# 1            Vab   100.00
# 2            Cbc    20.00
# 3            Vbc    20.00
# 4          alpha     0.02
# 5  Charging Cost    27.00
# 6            Zab   220.00
# 7            Zbc   120.00
# 8             Zo  2850.00

# %% [markdown]
# ### disposal constraint

# %%
for i in range(number_of_distribution_center):
    prob += Xbd[i]== lpSum(Xcb[i][j] for j in range(number_of_swapping_station))

# %% [markdown]
# ### Flow at swapping station

# %%
coef_for_C
# Out:
#                   Name Swapping station  Acquition cost  Rent + Labour 1  \
# 0        Shastri Nagar              Yc1          850000           240000
# 1             Jhotwara              Yc2          475000            96000
# 2             Chandpol              Yc3          850000           324000
# 3            modikhana              Yc4          850000           144000
# 4            Ghat gate              Yc5          475000            96000
# 5   Laxmi Narayan Puri              Yc6          850000           288000
# 6        Subhash Chowk              Yc7          850000           384000
# 7                 Amer              Yc8          475000           180000
# 8           Brahmapuri              Yc9          850000           264000
# 9        Malviya Nagar             Yc10          475000           324000
# 10          Mansarovar             yc11          850000           288000
# 11            Sanganer             yc12          475000           120000
# 12            Surajpol             yc13          475000            96000
# 13         Sindhi Camp             yc14          850000           384000
# 14           Raja park             yc15          475000           324000
#
#     Rent + Labour 3  Demand1  Demand3  Capacity
# 0            720000    18000    59580        50
# 1            288000    10000    33100        30
# 2            972000    16000    52960        50
# 3            432000    18000    59580        50
# 4            288000    11000    36410        30
# 5            864000    17000    56270        50
# 6           1152000    20000    66200       100
# 7            540000     9000    29790        30
# 8            792000    13000    43030        50
# 9            972000    11000    36410        30
# 10           864000    12000    39720        50
# 11           360000    16000    52960        30
# 12           288000    18000    59580        30
# 13          1152000    13000    43030        50
# 14           972000     7000    23170        30

# %%
for i in range(number_of_swapping_station):
    prob += lpSum(Xbc[j][i] for j in range(number_of_distribution_center))-lpSum(Xcb[j][i] for j in range(number_of_distribution_center))<= coef_for_C.iloc[i,3]*Yc[i]
    prob += lpSum(Xbc[j][i] for j in range(number_of_distribution_center))-lpSum(Xcb[j][i] for j in range(number_of_distribution_center))>=0

# %% [markdown]
# ### capacity constraint at distribution center

# %%
for i in range(number_of_distribution_center):
    prob += Xab[i]-Xbd[i]+ lpSum(Xcb[i][j] for j in range(number_of_distribution_center))-lpSum(Xbc[i][j] for j in range(number_of_distribution_center))<=coef_for_B.iloc[i,4]*Yb[i]
    prob +=  Xab[i]-Xbd[i]+ lpSum(Xcb[i][j] for j in range(number_of_distribution_center))-lpSum(Xbc[i][j] for j in range(number_of_distribution_center))>=0

# %% [markdown]
# ### demand constraint

# %%
coef_for_C
# Out:
#                   Name Swapping station  Acquition cost  Rent + Labour 1  \
# 0        Shastri Nagar              Yc1          850000           240000
# 1             Jhotwara              Yc2          475000            96000
# 2             Chandpol              Yc3          850000           324000
# 3            modikhana              Yc4          850000           144000
# 4            Ghat gate              Yc5          475000            96000
# 5   Laxmi Narayan Puri              Yc6          850000           288000
# 6        Subhash Chowk              Yc7          850000           384000
# 7                 Amer              Yc8          475000           180000
# 8           Brahmapuri              Yc9          850000           264000
# 9        Malviya Nagar             Yc10          475000           324000
# 10          Mansarovar             yc11          850000           288000
# 11            Sanganer             yc12          475000           120000
# 12            Surajpol             yc13          475000            96000
# 13         Sindhi Camp             yc14          850000           384000
# 14           Raja park             yc15          475000           324000
#
#     Rent + Labour 3  Demand1  Demand3  Capacity
# 0            720000    18000    59580        50
# 1            288000    10000    33100        30
# 2            972000    16000    52960        50
# 3            432000    18000    59580        50
# 4            288000    11000    36410        30
# 5            864000    17000    56270        50
# 6           1152000    20000    66200       100
# 7            540000     9000    29790        30
# 8            792000    13000    43030        50
# 9            972000    11000    36410        30
# 10           864000    12000    39720        50
# 11           360000    16000    52960        30
# 12           288000    18000    59580        30
# 13          1152000    13000    43030        50
# 14           972000     7000    23170        30

# %% [markdown]
# #### demand constraint for 1 year

# %%
prob += lpSum(Yc[i]*coef_for_C.iloc[i,5] for i in range(number_of_swapping_station))>=140000

# %% [markdown]
# #### demand constraint for 3 year

# %%
#prob += lpSum(Yc[i]*coef_for_C.iloc[i,6] for i in range(number_of_swapping_station))>=480000

# %% [markdown]
# ### Yc constraint

# %%
prob += lpSum(Yc[i] for i in range(number_of_swapping_station))>=6

# %% [markdown]
# ## objective I solution

# %%
prob
# Out:
# Cost:
# MINIMIZE
# 26.64*Xab_0 + 8.0*Xb0_c_0 + 9.0*Xb0_c_1 + 21.0*Xb0_c_10 + 26.0*Xb0_c_11 + 16.0*Xb0_c_12 + 12.0*Xb0_c_13 + 18.0*Xb0_c_14 + 13.0*Xb0_c_2 + 14.0*Xb0_c_3 + 16.0*Xb0_c_4 + 16.0*Xb0_c_5 + 15.0*Xb0_c_6 + 23.0*Xb0_c_7 + 15.0*Xb0_c_8 + 22.0*Xb0_c_9 + 8.0*Xb0_rev_c_0 + 9.0*Xb0_rev_c_1 + 21.0*Xb0_rev_c_10 + 26.0*Xb0_rev_c_11 + 16.0*Xb0_rev_c_12 + 12.0*Xb0_rev_c_13 + 18.0*Xb0_rev_c_14 + 13.0*Xb0_rev_c_2 + 14.0*Xb0_rev_c_3 + 16.0*Xb0_rev_c_4 + 16.0*Xb0_rev_c_5 + 15.0*Xb0_rev_c_6 + 23.0*Xb0_rev_c_7 + 15.0*Xb0_rev_c_8 + 22.0*Xb0_rev_c_9 + 400*Xdb_0 + 5500000*Yb_0 + 726000.0*Yc_0 + 366000.0*Yc_1 + 612000.0*Yc_10 + 552000.0*Yc_11 + 582000.0*Yc_12 + 735000.0*Yc_13 + 513000.0*Yc_14 + 756000.0*Yc_2 + 630000.0*Yc_3 + 393000.0*Yc_4 + 747000.0*Yc_5 + 924000.0*Yc_6 + 423000.0*Yc_7 + 615000.0*Yc_8 + 621000.0*Yc_9 + 0.0
# SUBJECT TO
# _C1: Xb0_rev_c_0 - 360 Yc_0 >= 0
#
# _C2: Xb0_rev_c_1 - 200 Yc_1 >= 0
#
# _C3: Xb0_rev_c_2 - 320 Yc_2 >= 0
#
# _C4: Xb0_rev_c_3 - 360 Yc_3 >= 0
#
# _C5: Xb0_rev_c_4 - 220 Yc_4 >= 0
#
# _C6: Xb0_rev_c_5 - 340 Yc_5 >= 0
#
# _C7: Xb0_rev_c_6 - 400 Yc_6 >= 0
#
# _C8: Xb0_rev_c_7 - 180 Yc_7 >= 0
#
# _C9: Xb0_rev_c_8 - 260 Yc_8 >= 0
#
# _C10: Xb0_rev_c_9 - 220 Yc_9 >= 0
#
# _C11: Xb0_rev_c_10 - 240 Yc_10 >= 0
#
# _C12: Xb0_rev_c_11 - 320 Yc_11 >= 0
#
# _C13: Xb0_rev_c_12 - 360 Yc_12 >= 0
#
# _C14: Xb0_rev_c_13 - 260 Yc_13 >= 0
#
# _C15: Xb0_rev_c_14 - 140 Yc_14 >= 0
#
# _C16: - 2e-05 Xb0_c_0 + Yb_0 >= 0
#
# _C17: - 2e-05 Xb0_rev_c_0 + Yb_0 >= 0
#
# _C18: - 2e-05 Xb0_c_1 + Yb_0 >= 0
#
# _C19: - 2e-05 Xb0_rev_c_1 + Yb_0 >= 0
#
# _C20: - 2e-05 Xb0_c_2 + Yb_0 >= 0
#
# _C21: - 2e-05 Xb0_rev_c_2 + Yb_0 >= 0
#
# _C22: - 2e-05 Xb0_c_3 + Yb_0 >= 0
#
# _C23: - 2e-05 Xb0_rev_c_3 + Yb_0 >= 0
#
# _C24: - 2e-05 Xb0_c_4 + Yb_0 >= 0
#
# _C25: - 2e-05 Xb0_rev_c_4 + Yb_0 >= 0
#
# _C26: - 2e-05 Xb0_c_5 + Yb_0 >= 0
#
# _C27: - 2e-05 Xb0_rev_c_5 + Yb_0 >= 0
#
# _C28: - 2e-05 Xb0_c_6 + Yb_0 >= 0
#
# _C29: - 2e-05 Xb0_rev_c_6 + Yb_0 >= 0
#
# _C30: - 2e-05 Xb0_c_7 + Yb_0 >= 0
#
# _C31: - 2e-05 Xb0_rev_c_7 + Yb_0 >= 0
#
# _C32: - 2e-05 Xb0_c_8 + Yb_0 >= 0
#
# _C33: - 2e-05 Xb0_rev_c_8 + Yb_0 >= 0
#
# _C34: - 2e-05 Xb0_c_9 + Yb_0 >= 0
#
# _C35: - 2e-05 Xb0_rev_c_9 + Yb_0 >= 0
#
# _C36: - 2e-05 Xb0_c_10 + Yb_0 >= 0
#
# _C37: - 2e-05 Xb0_rev_c_10 + Yb_0 >= 0
#
# _C38: - 2e-05 Xb0_c_11 + Yb_0 >= 0
#
# _C39: - 2e-05 Xb0_rev_c_11 + Yb_0 >= 0
#
# _C40: - 2e-05 Xb0_c_12 + Yb_0 >= 0
#
# _C41: - 2e-05 Xb0_rev_c_12 + Yb_0 >= 0
#
# _C42: - 2e-05 Xb0_c_13 + Yb_0 >= 0
#
# _C43: - 2e-05 Xb0_rev_c_13 + Yb_0 >= 0
#
# _C44: - 2e-05 Xb0_c_14 + Yb_0 >= 0
#
# _C45: - 2e-05 Xb0_rev_c_14 + Yb_0 >= 0
#
# _C46: - Xb0_rev_c_0 - Xb0_rev_c_1 - Xb0_rev_c_10 - Xb0_rev_c_11 - Xb0_rev_c_12
#  - Xb0_rev_c_13 - Xb0_rev_c_14 - Xb0_rev_c_2 - Xb0_rev_c_3 - Xb0_rev_c_4
#  - Xb0_rev_c_5 - Xb0_rev_c_6 - Xb0_rev_c_7 - Xb0_rev_c_8 - Xb0_rev_c_9 + Xdb_0
#  = 0
#
# _C47: Xb0_c_0 - Xb0_rev_c_0 - 240000 Yc_0 <= 0
#
# _C48: Xb0_c_0 - Xb0_rev_c_0 >= 0
#
# _C49: Xb0_c_1 - Xb0_rev_c_1 - 96000 Yc_1 <= 0
#
# _C50: Xb0_c_1 - Xb0_rev_c_1 >= 0
#
# _C51: Xb0_c_2 - Xb0_rev_c_2 - 324000 Yc_2 <= 0
#
# _C52: Xb0_c_2 - Xb0_rev_c_2 >= 0
#
# _C53: Xb0_c_3 - Xb0_rev_c_3 - 144000 Yc_3 <= 0
#
# _C54: Xb0_c_3 - Xb0_rev_c_3 >= 0
#
# _C55: Xb0_c_4 - Xb0_rev_c_4 - 96000 Yc_4 <= 0
#
# _C56: Xb0_c_4 - Xb0_rev_c_4 >= 0
#
# _C57: Xb0_c_5 - Xb0_rev_c_5 - 288000 Yc_5 <= 0
#
# _C58: Xb0_c_5 - Xb0_rev_c_5 >= 0
#
# _C59: Xb0_c_6 - Xb0_rev_c_6 - 384000 Yc_6 <= 0
#
# _C60: Xb0_c_6 - Xb0_rev_c_6 >= 0
#
# _C61: Xb0_c_7 - Xb0_rev_c_7 - 180000 Yc_7 <= 0
#
# _C62: Xb0_c_7 - Xb0_rev_c_7 >= 0
#
# _C63: Xb0_c_8 - Xb0_rev_c_8 - 264000 Yc_8 <= 0
#
# _C64: Xb0_c_8 - Xb0_rev_c_8 >= 0
#
# _C65: Xb0_c_9 - Xb0_rev_c_9 - 324000 Yc_9 <= 0
#
# _C66: Xb0_c_9 - Xb0_rev_c_9 >= 0
#
# _C67: Xb0_c_10 - Xb0_rev_c_10 - 288000 Yc_10 <= 0
#
# _C68: Xb0_c_10 - Xb0_rev_c_10 >= 0
#
# _C69: Xb0_c_11 - Xb0_rev_c_11 - 120000 Yc_11 <= 0
#
# _C70: Xb0_c_11 - Xb0_rev_c_11 >= 0
#
# _C71: Xb0_c_12 - Xb0_rev_c_12 - 96000 Yc_12 <= 0
#
# _C72: Xb0_c_12 - Xb0_rev_c_12 >= 0
#
# _C73: Xb0_c_13 - Xb0_rev_c_13 - 384000 Yc_13 <= 0
#
# _C74: Xb0_c_13 - Xb0_rev_c_13 >= 0
#
# _C75: Xb0_c_14 - Xb0_rev_c_14 - 324000 Yc_14 <= 0
#
# _C76: Xb0_c_14 - Xb0_rev_c_14 >= 0
#
# _C77: Xab_0 - Xb0_c_0 + Xb0_rev_c_0 - Xdb_0 - 13500000 Yb_0 <= 0
#
# _C78: Xab_0 - Xb0_c_0 + Xb0_rev_c_0 - Xdb_0 >= 0
#
# _C79: 18000 Yc_0 + 10000 Yc_1 + 12000 Yc_10 + 16000 Yc_11 + 18000 Yc_12
#  + 13000 Yc_13 + 7000 Yc_14 + 16000 Yc_2 + 18000 Yc_3 + 11000 Yc_4
#  + 17000 Yc_5 + 20000 Yc_6 + 9000 Yc_7 + 13000 Yc_8 + 11000 Yc_9 >= 140000
#
# _C80: Yc_0 + Yc_1 + Yc_10 + Yc_11 + Yc_12 + Yc_13 + Yc_14 + Yc_2 + Yc_3 + Yc_4
#  + Yc_5 + Yc_6 + Yc_7 + Yc_8 + Yc_9 >= 6
#
# VARIABLES
# 0 <= Xab_0 Integer
# 0 <= Xb0_c_0 Integer
# 0 <= Xb0_c_1 Integer
# 0 <= Xb0_c_10 Integer
# 0 <= Xb0_c_11 Integer
# 0 <= Xb0_c_12 Integer
# 0 <= Xb0_c_13 Integer
# 0 <= Xb0_c_14 Integer
# 0 <= Xb0_c_2 Integer
# 0 <= Xb0_c_3 Integer
# 0 <= Xb0_c_4 Integer
# 0 <= Xb0_c_5 Integer
# 0 <= Xb0_c_6 Integer
# 0 <= Xb0_c_7 Integer
# 0 <= Xb0_c_8 Integer
# 0 <= Xb0_c_9 Integer
# 0 <= Xb0_rev_c_0 Integer
# 0 <= Xb0_rev_c_1 Integer
# 0 <= Xb0_rev_c_10 Integer
# 0 <= Xb0_rev_c_11 Integer
# 0 <= Xb0_rev_c_12 Integer
# 0 <= Xb0_rev_c_13 Integer
# 0 <= Xb0_rev_c_14 Integer
# 0 <= Xb0_rev_c_2 Integer
# 0 <= Xb0_rev_c_3 Integer
# 0 <= Xb0_rev_c_4 Integer
# 0 <= Xb0_rev_c_5 Integer
# 0 <= Xb0_rev_c_6 Integer
# 0 <= Xb0_rev_c_7 Integer
# 0 <= Xb0_rev_c_8 Integer
# 0 <= Xb0_rev_c_9 Integer
# 0 <= Xdb_0 Integer
# 0 <= Yb_0 <= 1 Integer
# 0 <= Yc_0 <= 1 Integer
# 0 <= Yc_1 <= 1 Integer
# 0 <= Yc_10 <= 1 Integer
# 0 <= Yc_11 <= 1 Integer
# 0 <= Yc_12 <= 1 Integer
# 0 <= Yc_13 <= 1 Integer
# 0 <= Yc_14 <= 1 Integer
# 0 <= Yc_2 <= 1 Integer
# 0 <= Yc_3 <= 1 Integer
# 0 <= Yc_4 <= 1 Integer
# 0 <= Yc_5 <= 1 Integer
# 0 <= Yc_6 <= 1 Integer
# 0 <= Yc_7 <= 1 Integer
# 0 <= Yc_8 <= 1 Integer
# 0 <= Yc_9 <= 1 Integer

# %%
prob.solve()
# Out:
# 1

# %%
LpStatus[prob.solve()]
# Out:
# 'Optimal'

# %%
for variables in prob.variables():
    print( variables.name+'   '+ str(variables.value()))
# Out:
# Xab_0   2800.0
# Xb0_c_0   360.0
# Xb0_c_1   200.0
# Xb0_c_10   240.0
# Xb0_c_11   320.0
# Xb0_c_12   360.0
# Xb0_c_13   0.0
# Xb0_c_14   0.0
# Xb0_c_2   0.0
# Xb0_c_3   360.0
# Xb0_c_4   220.0
# Xb0_c_5   340.0
# Xb0_c_6   400.0
# Xb0_c_7   0.0
# Xb0_c_8   0.0
# Xb0_c_9   0.0
# Xb0_rev_c_0   360.0
# Xb0_rev_c_1   200.0
# Xb0_rev_c_10   240.0
# Xb0_rev_c_11   320.0
# Xb0_rev_c_12   360.0
# Xb0_rev_c_13   0.0
# Xb0_rev_c_14   0.0
# Xb0_rev_c_2   0.0
# Xb0_rev_c_3   360.0
# Xb0_rev_c_4   220.0
# Xb0_rev_c_5   340.0
# Xb0_rev_c_6   400.0
# Xb0_rev_c_7   0.0
# Xb0_rev_c_8   0.0
# Xb0_rev_c_9   0.0
# Xdb_0   2800.0
# Yb_0   1.0
# Yc_0   1.0
# Yc_1   1.0
# Yc_10   1.0
# Yc_11   1.0
# Yc_12   1.0
# Yc_13   0.0
# Yc_14   0.0
# Yc_2   0.0
# Yc_3   1.0
# Yc_4   1.0
# Yc_5   1.0
# Yc_6   1.0
# Yc_7   0.0
# Yc_8   0.0
# Yc_9   0.0

# %% [markdown]
# ## II objective

# %% [markdown]
# ### Data

# %%
coef_for_B
# Out:
#   Unnamed: 0      Acq  Disposal Cost  Rent + Labour 1  Rent + Labour 3  \
# 0        Yb1  1000000            400          4500000         13500000
#
#    Capacity
# 0     18000

# %%
coef_for_C
# Out:
#                   Name Swapping station  Acquition cost  Rent + Labour 1  \
# 0        Shastri Nagar              Yc1          850000           240000
# 1             Jhotwara              Yc2          475000            96000
# 2             Chandpol              Yc3          850000           324000
# 3            modikhana              Yc4          850000           144000
# 4            Ghat gate              Yc5          475000            96000
# 5   Laxmi Narayan Puri              Yc6          850000           288000
# 6        Subhash Chowk              Yc7          850000           384000
# 7                 Amer              Yc8          475000           180000
# 8           Brahmapuri              Yc9          850000           264000
# 9        Malviya Nagar             Yc10          475000           324000
# 10          Mansarovar             yc11          850000           288000
# 11            Sanganer             yc12          475000           120000
# 12            Surajpol             yc13          475000            96000
# 13         Sindhi Camp             yc14          850000           384000
# 14           Raja park             yc15          475000           324000
#
#     Rent + Labour 3  Demand1  Demand3  Capacity
# 0            720000    18000    59580        50
# 1            288000    10000    33100        30
# 2            972000    16000    52960        50
# 3            432000    18000    59580        50
# 4            288000    11000    36410        30
# 5            864000    17000    56270        50
# 6           1152000    20000    66200       100
# 7            540000     9000    29790        30
# 8            792000    13000    43030        50
# 9            972000    11000    36410        30
# 10           864000    12000    39720        50
# 11           360000    16000    52960        30
# 12           288000    18000    59580        30
# 13          1152000    13000    43030        50
# 14           972000     7000    23170        30

# %%
constants
# Out:
#            const    value
# 0            Cab    12.00
# 1            Vab   100.00
# 2            Cbc    20.00
# 3            Vbc    20.00
# 4          alpha     0.02
# 5  Charging Cost    27.00
# 6            Zab   220.00
# 7            Zbc   120.00
# 8             Zo  2850.00

# %% [markdown]
# ### Emission between A nad B

# %%
dist_A_to_B
# Out:
#     flow  dist
# 0  Xa1b1   222

# %%
emission_AB = lpSum(constants.iloc[6,1]*Xab[i]*dist_A_to_B.iloc[i,1]*(1/constants.iloc[1,1]) for i in range(number_of_distribution_center))
emission_AB
# Out:
# 488.40000000000003*Xab_0 + 0.0

# %% [markdown]
# ### emission between B and C

# %%
k = 1/constants.iloc[3,1]
list_of_emission_bc = []
j=0
for m in range(number_of_distribution_center):
    list_of_emission_bc.append([constants.iloc[7,1]*distance_BC.iloc[i+j,1]*Xbc[m][i]*k for i in range(number_of_swapping_station)])
    j=j+10

# %%
print(list_of_emission_bc)
# Out:
# [[48.0*Xb0_c_0 + 0.0, 54.0*Xb0_c_1 + 0.0, 78.0*Xb0_c_2 + 0.0, 84.0*Xb0_c_3 + 0.0, 96.0*Xb0_c_4 + 0.0, 96.0*Xb0_c_5 + 0.0, 90.0*Xb0_c_6 + 0.0, 138.0*Xb0_c_7 + 0.0, 90.0*Xb0_c_8 + 0.0, 132.0*Xb0_c_9 + 0.0, 126.0*Xb0_c_10 + 0.0, 156.0*Xb0_c_11 + 0.0, 96.0*Xb0_c_12 + 0.0, 72.0*Xb0_c_13 + 0.0, 108.0*Xb0_c_14 + 0.0]]

# %% [markdown]
# ### emission between C and B

# %%
k = 1/constants.iloc[3,1]
list_of_emission_cb = []
j=0
for m in range(number_of_distribution_center):
    list_of_emission_cb.append([120*distance_BC.iloc[i+j,1]*Xcb[m][i]*k for i in range(number_of_swapping_station)])
    j=j+10

# %%
print(list_of_emission_cb)
# Out:
# [[48.0*Xb0_rev_c_0 + 0.0, 54.0*Xb0_rev_c_1 + 0.0, 78.0*Xb0_rev_c_2 + 0.0, 84.0*Xb0_rev_c_3 + 0.0, 96.0*Xb0_rev_c_4 + 0.0, 96.0*Xb0_rev_c_5 + 0.0, 90.0*Xb0_rev_c_6 + 0.0, 138.0*Xb0_rev_c_7 + 0.0, 90.0*Xb0_rev_c_8 + 0.0, 132.0*Xb0_rev_c_9 + 0.0, 126.0*Xb0_rev_c_10 + 0.0, 156.0*Xb0_rev_c_11 + 0.0, 96.0*Xb0_rev_c_12 + 0.0, 72.0*Xb0_rev_c_13 + 0.0, 108.0*Xb0_rev_c_14 + 0.0]]

# %% [markdown]
# ### emission between B and C operations

# %%
emission_BC_op_1 = lpSum(constants.iloc[8,1]*coef_for_C.iloc[i,5]*Yc[i] for i in range(number_of_swapping_station))
emission_BC_op_1
# Out:
# 51300000.0*Yc_0 + 28500000.0*Yc_1 + 34200000.0*Yc_10 + 45600000.0*Yc_11 + 51300000.0*Yc_12 + 37050000.0*Yc_13 + 19950000.0*Yc_14 + 45600000.0*Yc_2 + 51300000.0*Yc_3 + 31350000.0*Yc_4 + 48450000.0*Yc_5 + 57000000.0*Yc_6 + 25650000.0*Yc_7 + 37050000.0*Yc_8 + 31350000.0*Yc_9 + 0.0

# %%
emission_BC_op_3 = lpSum(constants.iloc[8,1]*coef_for_C.iloc[i,6]*Yc[i] for i in range(number_of_swapping_station))
emission_BC_op_3
# Out:
# 169803000.0*Yc_0 + 94335000.0*Yc_1 + 113202000.0*Yc_10 + 150936000.0*Yc_11 + 169803000.0*Yc_12 + 122635500.0*Yc_13 + 66034500.0*Yc_14 + 150936000.0*Yc_2 + 169803000.0*Yc_3 + 103768500.0*Yc_4 + 160369500.0*Yc_5 + 188670000.0*Yc_6 + 84901500.0*Yc_7 + 122635500.0*Yc_8 + 103768500.0*Yc_9 + 0.0

# %% [markdown]
# ### Emission objective

# %%
prob2 = LpProblem('emission',LpMinimize)
prob2 += lpSum(emission_AB+list_of_emission_bc+emission_BC_op_3+list_of_emission_cb)
prob2
# Out:
# emission:
# MINIMIZE
# 488.40000000000003*Xab_0 + 48.0*Xb0_c_0 + 54.0*Xb0_c_1 + 126.0*Xb0_c_10 + 156.0*Xb0_c_11 + 96.0*Xb0_c_12 + 72.0*Xb0_c_13 + 108.0*Xb0_c_14 + 78.0*Xb0_c_2 + 84.0*Xb0_c_3 + 96.0*Xb0_c_4 + 96.0*Xb0_c_5 + 90.0*Xb0_c_6 + 138.0*Xb0_c_7 + 90.0*Xb0_c_8 + 132.0*Xb0_c_9 + 48.0*Xb0_rev_c_0 + 54.0*Xb0_rev_c_1 + 126.0*Xb0_rev_c_10 + 156.0*Xb0_rev_c_11 + 96.0*Xb0_rev_c_12 + 72.0*Xb0_rev_c_13 + 108.0*Xb0_rev_c_14 + 78.0*Xb0_rev_c_2 + 84.0*Xb0_rev_c_3 + 96.0*Xb0_rev_c_4 + 96.0*Xb0_rev_c_5 + 90.0*Xb0_rev_c_6 + 138.0*Xb0_rev_c_7 + 90.0*Xb0_rev_c_8 + 132.0*Xb0_rev_c_9 + 169803000.0*Yc_0 + 94335000.0*Yc_1 + 113202000.0*Yc_10 + 150936000.0*Yc_11 + 169803000.0*Yc_12 + 122635500.0*Yc_13 + 66034500.0*Yc_14 + 150936000.0*Yc_2 + 169803000.0*Yc_3 + 103768500.0*Yc_4 + 160369500.0*Yc_5 + 188670000.0*Yc_6 + 84901500.0*Yc_7 + 122635500.0*Yc_8 + 103768500.0*Yc_9 + 0.0
# VARIABLES
# 0 <= Xab_0 Integer
# 0 <= Xb0_c_0 Integer
# 0 <= Xb0_c_1 Integer
# 0 <= Xb0_c_10 Integer
# 0 <= Xb0_c_11 Integer
# 0 <= Xb0_c_12 Integer
# 0 <= Xb0_c_13 Integer
# 0 <= Xb0_c_14 Integer
# 0 <= Xb0_c_2 Integer
# 0 <= Xb0_c_3 Integer
# 0 <= Xb0_c_4 Integer
# 0 <= Xb0_c_5 Integer
# 0 <= Xb0_c_6 Integer
# 0 <= Xb0_c_7 Integer
# 0 <= Xb0_c_8 Integer
# 0 <= Xb0_c_9 Integer
# 0 <= Xb0_rev_c_0 Integer
# 0 <= Xb0_rev_c_1 Integer
# 0 <= Xb0_rev_c_10 Integer
# 0 <= Xb0_rev_c_11 Integer
# 0 <= Xb0_rev_c_12 Integer
# 0 <= Xb0_rev_c_13 Integer
# 0 <= Xb0_rev_c_14 Integer
# 0 <= Xb0_rev_c_2 Integer
# 0 <= Xb0_rev_c_3 Integer
# 0 <= Xb0_rev_c_4 Integer
# 0 <= Xb0_rev_c_5 Integer
# 0 <= Xb0_rev_c_6 Integer
# 0 <= Xb0_rev_c_7 Integer
# 0 <= Xb0_rev_c_8 Integer
# 0 <= Xb0_rev_c_9 Integer
# 0 <= Yc_0 <= 1 Integer
# 0 <= Yc_1 <= 1 Integer
# 0 <= Yc_10 <= 1 Integer
# 0 <= Yc_11 <= 1 Integer
# 0 <= Yc_12 <= 1 Integer
# 0 <= Yc_13 <= 1 Integer
# 0 <= Yc_14 <= 1 Integer
# 0 <= Yc_2 <= 1 Integer
# 0 <= Yc_3 <= 1 Integer
# 0 <= Yc_4 <= 1 Integer
# 0 <= Yc_5 <= 1 Integer
# 0 <= Yc_6 <= 1 Integer
# 0 <= Yc_7 <= 1 Integer
# 0 <= Yc_8 <= 1 Integer
# 0 <= Yc_9 <= 1 Integer

# %% [markdown]
# ### IInd objective

# %%
cons = {}
for i in range(len(prob.constraints.values())):
    cons[i] = list(prob.constraints.values())[i]

# %%
for i in range(len(cons)):
    prob2 += cons[i]

# %%
prob2
# Out:
# emission:
# MINIMIZE
# 488.40000000000003*Xab_0 + 48.0*Xb0_c_0 + 54.0*Xb0_c_1 + 126.0*Xb0_c_10 + 156.0*Xb0_c_11 + 96.0*Xb0_c_12 + 72.0*Xb0_c_13 + 108.0*Xb0_c_14 + 78.0*Xb0_c_2 + 84.0*Xb0_c_3 + 96.0*Xb0_c_4 + 96.0*Xb0_c_5 + 90.0*Xb0_c_6 + 138.0*Xb0_c_7 + 90.0*Xb0_c_8 + 132.0*Xb0_c_9 + 48.0*Xb0_rev_c_0 + 54.0*Xb0_rev_c_1 + 126.0*Xb0_rev_c_10 + 156.0*Xb0_rev_c_11 + 96.0*Xb0_rev_c_12 + 72.0*Xb0_rev_c_13 + 108.0*Xb0_rev_c_14 + 78.0*Xb0_rev_c_2 + 84.0*Xb0_rev_c_3 + 96.0*Xb0_rev_c_4 + 96.0*Xb0_rev_c_5 + 90.0*Xb0_rev_c_6 + 138.0*Xb0_rev_c_7 + 90.0*Xb0_rev_c_8 + 132.0*Xb0_rev_c_9 + 169803000.0*Yc_0 + 94335000.0*Yc_1 + 113202000.0*Yc_10 + 150936000.0*Yc_11 + 169803000.0*Yc_12 + 122635500.0*Yc_13 + 66034500.0*Yc_14 + 150936000.0*Yc_2 + 169803000.0*Yc_3 + 103768500.0*Yc_4 + 160369500.0*Yc_5 + 188670000.0*Yc_6 + 84901500.0*Yc_7 + 122635500.0*Yc_8 + 103768500.0*Yc_9 + 0.0
# SUBJECT TO
# _C1: Xb0_rev_c_0 - 360 Yc_0 >= 0
#
# _C2: Xb0_rev_c_1 - 200 Yc_1 >= 0
#
# _C3: Xb0_rev_c_2 - 320 Yc_2 >= 0
#
# _C4: Xb0_rev_c_3 - 360 Yc_3 >= 0
#
# _C5: Xb0_rev_c_4 - 220 Yc_4 >= 0
#
# _C6: Xb0_rev_c_5 - 340 Yc_5 >= 0
#
# _C7: Xb0_rev_c_6 - 400 Yc_6 >= 0
#
# _C8: Xb0_rev_c_7 - 180 Yc_7 >= 0
#
# _C9: Xb0_rev_c_8 - 260 Yc_8 >= 0
#
# _C10: Xb0_rev_c_9 - 220 Yc_9 >= 0
#
# _C11: Xb0_rev_c_10 - 240 Yc_10 >= 0
#
# _C12: Xb0_rev_c_11 - 320 Yc_11 >= 0
#
# _C13: Xb0_rev_c_12 - 360 Yc_12 >= 0
#
# _C14: Xb0_rev_c_13 - 260 Yc_13 >= 0
#
# _C15: Xb0_rev_c_14 - 140 Yc_14 >= 0
#
# _C16: - 2e-05 Xb0_c_0 + Yb_0 >= 0
#
# _C17: - 2e-05 Xb0_rev_c_0 + Yb_0 >= 0
#
# _C18: - 2e-05 Xb0_c_1 + Yb_0 >= 0
#
# _C19: - 2e-05 Xb0_rev_c_1 + Yb_0 >= 0
#
# _C20: - 2e-05 Xb0_c_2 + Yb_0 >= 0
#
# _C21: - 2e-05 Xb0_rev_c_2 + Yb_0 >= 0
#
# _C22: - 2e-05 Xb0_c_3 + Yb_0 >= 0
#
# _C23: - 2e-05 Xb0_rev_c_3 + Yb_0 >= 0
#
# _C24: - 2e-05 Xb0_c_4 + Yb_0 >= 0
#
# _C25: - 2e-05 Xb0_rev_c_4 + Yb_0 >= 0
#
# _C26: - 2e-05 Xb0_c_5 + Yb_0 >= 0
#
# _C27: - 2e-05 Xb0_rev_c_5 + Yb_0 >= 0
#
# _C28: - 2e-05 Xb0_c_6 + Yb_0 >= 0
#
# _C29: - 2e-05 Xb0_rev_c_6 + Yb_0 >= 0
#
# _C30: - 2e-05 Xb0_c_7 + Yb_0 >= 0
#
# _C31: - 2e-05 Xb0_rev_c_7 + Yb_0 >= 0
#
# _C32: - 2e-05 Xb0_c_8 + Yb_0 >= 0
#
# _C33: - 2e-05 Xb0_rev_c_8 + Yb_0 >= 0
#
# _C34: - 2e-05 Xb0_c_9 + Yb_0 >= 0
#
# _C35: - 2e-05 Xb0_rev_c_9 + Yb_0 >= 0
#
# _C36: - 2e-05 Xb0_c_10 + Yb_0 >= 0
#
# _C37: - 2e-05 Xb0_rev_c_10 + Yb_0 >= 0
#
# _C38: - 2e-05 Xb0_c_11 + Yb_0 >= 0
#
# _C39: - 2e-05 Xb0_rev_c_11 + Yb_0 >= 0
#
# _C40: - 2e-05 Xb0_c_12 + Yb_0 >= 0
#
# _C41: - 2e-05 Xb0_rev_c_12 + Yb_0 >= 0
#
# _C42: - 2e-05 Xb0_c_13 + Yb_0 >= 0
#
# _C43: - 2e-05 Xb0_rev_c_13 + Yb_0 >= 0
#
# _C44: - 2e-05 Xb0_c_14 + Yb_0 >= 0
#
# _C45: - 2e-05 Xb0_rev_c_14 + Yb_0 >= 0
#
# _C46: - Xb0_rev_c_0 - Xb0_rev_c_1 - Xb0_rev_c_10 - Xb0_rev_c_11 - Xb0_rev_c_12
#  - Xb0_rev_c_13 - Xb0_rev_c_14 - Xb0_rev_c_2 - Xb0_rev_c_3 - Xb0_rev_c_4
#  - Xb0_rev_c_5 - Xb0_rev_c_6 - Xb0_rev_c_7 - Xb0_rev_c_8 - Xb0_rev_c_9 + Xdb_0
#  = 0
#
# _C47: Xb0_c_0 - Xb0_rev_c_0 - 240000 Yc_0 <= 0
#
# _C48: Xb0_c_0 - Xb0_rev_c_0 >= 0
#
# _C49: Xb0_c_1 - Xb0_rev_c_1 - 96000 Yc_1 <= 0
#
# _C50: Xb0_c_1 - Xb0_rev_c_1 >= 0
#
# _C51: Xb0_c_2 - Xb0_rev_c_2 - 324000 Yc_2 <= 0
#
# _C52: Xb0_c_2 - Xb0_rev_c_2 >= 0
#
# _C53: Xb0_c_3 - Xb0_rev_c_3 - 144000 Yc_3 <= 0
#
# _C54: Xb0_c_3 - Xb0_rev_c_3 >= 0
#
# _C55: Xb0_c_4 - Xb0_rev_c_4 - 96000 Yc_4 <= 0
#
# _C56: Xb0_c_4 - Xb0_rev_c_4 >= 0
#
# _C57: Xb0_c_5 - Xb0_rev_c_5 - 288000 Yc_5 <= 0
#
# _C58: Xb0_c_5 - Xb0_rev_c_5 >= 0
#
# _C59: Xb0_c_6 - Xb0_rev_c_6 - 384000 Yc_6 <= 0
#
# _C60: Xb0_c_6 - Xb0_rev_c_6 >= 0
#
# _C61: Xb0_c_7 - Xb0_rev_c_7 - 180000 Yc_7 <= 0
#
# _C62: Xb0_c_7 - Xb0_rev_c_7 >= 0
#
# _C63: Xb0_c_8 - Xb0_rev_c_8 - 264000 Yc_8 <= 0
#
# _C64: Xb0_c_8 - Xb0_rev_c_8 >= 0
#
# _C65: Xb0_c_9 - Xb0_rev_c_9 - 324000 Yc_9 <= 0
#
# _C66: Xb0_c_9 - Xb0_rev_c_9 >= 0
#
# _C67: Xb0_c_10 - Xb0_rev_c_10 - 288000 Yc_10 <= 0
#
# _C68: Xb0_c_10 - Xb0_rev_c_10 >= 0
#
# _C69: Xb0_c_11 - Xb0_rev_c_11 - 120000 Yc_11 <= 0
#
# _C70: Xb0_c_11 - Xb0_rev_c_11 >= 0
#
# _C71: Xb0_c_12 - Xb0_rev_c_12 - 96000 Yc_12 <= 0
#
# _C72: Xb0_c_12 - Xb0_rev_c_12 >= 0
#
# _C73: Xb0_c_13 - Xb0_rev_c_13 - 384000 Yc_13 <= 0
#
# _C74: Xb0_c_13 - Xb0_rev_c_13 >= 0
#
# _C75: Xb0_c_14 - Xb0_rev_c_14 - 324000 Yc_14 <= 0
#
# _C76: Xb0_c_14 - Xb0_rev_c_14 >= 0
#
# _C77: Xab_0 - Xb0_c_0 + Xb0_rev_c_0 - Xdb_0 - 13500000 Yb_0 <= 0
#
# _C78: Xab_0 - Xb0_c_0 + Xb0_rev_c_0 - Xdb_0 >= 0
#
# _C79: 18000 Yc_0 + 10000 Yc_1 + 12000 Yc_10 + 16000 Yc_11 + 18000 Yc_12
#  + 13000 Yc_13 + 7000 Yc_14 + 16000 Yc_2 + 18000 Yc_3 + 11000 Yc_4
#  + 17000 Yc_5 + 20000 Yc_6 + 9000 Yc_7 + 13000 Yc_8 + 11000 Yc_9 >= 140000
#
# _C80: Yc_0 + Yc_1 + Yc_10 + Yc_11 + Yc_12 + Yc_13 + Yc_14 + Yc_2 + Yc_3 + Yc_4
#  + Yc_5 + Yc_6 + Yc_7 + Yc_8 + Yc_9 >= 6
#
# VARIABLES
# 0 <= Xab_0 Integer
# 0 <= Xb0_c_0 Integer
# 0 <= Xb0_c_1 Integer
# 0 <= Xb0_c_10 Integer
# 0 <= Xb0_c_11 Integer
# 0 <= Xb0_c_12 Integer
# 0 <= Xb0_c_13 Integer
# 0 <= Xb0_c_14 Integer
# 0 <= Xb0_c_2 Integer
# 0 <= Xb0_c_3 Integer
# 0 <= Xb0_c_4 Integer
# 0 <= Xb0_c_5 Integer
# 0 <= Xb0_c_6 Integer
# 0 <= Xb0_c_7 Integer
# 0 <= Xb0_c_8 Integer
# 0 <= Xb0_c_9 Integer
# 0 <= Xb0_rev_c_0 Integer
# 0 <= Xb0_rev_c_1 Integer
# 0 <= Xb0_rev_c_10 Integer
# 0 <= Xb0_rev_c_11 Integer
# 0 <= Xb0_rev_c_12 Integer
# 0 <= Xb0_rev_c_13 Integer
# 0 <= Xb0_rev_c_14 Integer
# 0 <= Xb0_rev_c_2 Integer
# 0 <= Xb0_rev_c_3 Integer
# 0 <= Xb0_rev_c_4 Integer
# 0 <= Xb0_rev_c_5 Integer
# 0 <= Xb0_rev_c_6 Integer
# 0 <= Xb0_rev_c_7 Integer
# 0 <= Xb0_rev_c_8 Integer
# 0 <= Xb0_rev_c_9 Integer
# 0 <= Xdb_0 Integer
# 0 <= Yb_0 <= 1 Integer
# 0 <= Yc_0 <= 1 Integer
# 0 <= Yc_1 <= 1 Integer
# 0 <= Yc_10 <= 1 Integer
# 0 <= Yc_11 <= 1 Integer
# 0 <= Yc_12 <= 1 Integer
# 0 <= Yc_13 <= 1 Integer
# 0 <= Yc_14 <= 1 Integer
# 0 <= Yc_2 <= 1 Integer
# 0 <= Yc_3 <= 1 Integer
# 0 <= Yc_4 <= 1 Integer
# 0 <= Yc_5 <= 1 Integer
# 0 <= Yc_6 <= 1 Integer
# 0 <= Yc_7 <= 1 Integer
# 0 <= Yc_8 <= 1 Integer
# 0 <= Yc_9 <= 1 Integer

# %%
prob2.solve()
# Out:
# 1

# %%
LpStatus[prob2.solve()]
# Out:
# 'Optimal'

# %%
for variables in prob2.variables():
    print( variables.name+'   '+ str(variables.value()))
# Out:
# Xab_0   2800.0
# Xb0_c_0   360.0
# Xb0_c_1   0.0
# Xb0_c_10   0.0
# Xb0_c_11   0.0
# Xb0_c_12   360.0
# Xb0_c_13   260.0
# Xb0_c_14   140.0
# Xb0_c_2   320.0
# Xb0_c_3   360.0
# Xb0_c_4   0.0
# Xb0_c_5   340.0
# Xb0_c_6   400.0
# Xb0_c_7   0.0
# Xb0_c_8   260.0
# Xb0_c_9   0.0
# Xb0_rev_c_0   360.0
# Xb0_rev_c_1   0.0
# Xb0_rev_c_10   0.0
# Xb0_rev_c_11   0.0
# Xb0_rev_c_12   360.0
# Xb0_rev_c_13   260.0
# Xb0_rev_c_14   140.0
# Xb0_rev_c_2   320.0
# Xb0_rev_c_3   360.0
# Xb0_rev_c_4   0.0
# Xb0_rev_c_5   340.0
# Xb0_rev_c_6   400.0
# Xb0_rev_c_7   0.0
# Xb0_rev_c_8   260.0
# Xb0_rev_c_9   0.0
# Xdb_0   2800.0
# Yb_0   1.0
# Yc_0   1.0
# Yc_1   0.0
# Yc_10   0.0
# Yc_11   0.0
# Yc_12   1.0
# Yc_13   1.0
# Yc_14   1.0
# Yc_2   1.0
# Yc_3   1.0
# Yc_4   0.0
# Yc_5   1.0
# Yc_6   1.0
# Yc_7   0.0
# Yc_8   1.0
# Yc_9   0.0

# %%
prob2.objective.value()
# Out:
# 1322523360.0

# %% [markdown]
# ## E constraint

# %%
obj = {
    0:prob.objective,
    1:prob2.objective,
}

# %%
obj
# Out:
# {0: 26.64*Xab_0 + 8.0*Xb0_c_0 + 9.0*Xb0_c_1 + 21.0*Xb0_c_10 + 26.0*Xb0_c_11 + 16.0*Xb0_c_12 + 12.0*Xb0_c_13 + 18.0*Xb0_c_14 + 13.0*Xb0_c_2 + 14.0*Xb0_c_3 + 16.0*Xb0_c_4 + 16.0*Xb0_c_5 + 15.0*Xb0_c_6 + 23.0*Xb0_c_7 + 15.0*Xb0_c_8 + 22.0*Xb0_c_9 + 8.0*Xb0_rev_c_0 + 9.0*Xb0_rev_c_1 + 21.0*Xb0_rev_c_10 + 26.0*Xb0_rev_c_11 + 16.0*Xb0_rev_c_12 + 12.0*Xb0_rev_c_13 + 18.0*Xb0_rev_c_14 + 13.0*Xb0_rev_c_2 + 14.0*Xb0_rev_c_3 + 16.0*Xb0_rev_c_4 + 16.0*Xb0_rev_c_5 + 15.0*Xb0_rev_c_6 + 23.0*Xb0_rev_c_7 + 15.0*Xb0_rev_c_8 + 22.0*Xb0_rev_c_9 + 400*Xdb_0 + 5500000*Yb_0 + 726000.0*Yc_0 + 366000.0*Yc_1 + 612000.0*Yc_10 + 552000.0*Yc_11 + 582000.0*Yc_12 + 735000.0*Yc_13 + 513000.0*Yc_14 + 756000.0*Yc_2 + 630000.0*Yc_3 + 393000.0*Yc_4 + 747000.0*Yc_5 + 924000.0*Yc_6 + 423000.0*Yc_7 + 615000.0*Yc_8 + 621000.0*Yc_9 + 0.0,
#  1: 488.40000000000003*Xab_0 + 48.0*Xb0_c_0 + 54.0*Xb0_c_1 + 126.0*Xb0_c_10 + 156.0*Xb0_c_11 + 96.0*Xb0_c_12 + 72.0*Xb0_c_13 + 108.0*Xb0_c_14 + 78.0*Xb0_c_2 + 84.0*Xb0_c_3 + 96.0*Xb0_c_4 + 96.0*Xb0_c_5 + 90.0*Xb0_c_6 + 138.0*Xb0_c_7 + 90.0*Xb0_c_8 + 132.0*Xb0_c_9 + 48.0*Xb0_rev_c_0 + 54.0*Xb0_rev_c_1 + 126.0*Xb0_rev_c_10 + 156.0*Xb0_rev_c_11 + 96.0*Xb0_rev_c_12 + 72.0*Xb0_rev_c_13 + 108.0*Xb0_rev_c_14 + 78.0*Xb0_rev_c_2 + 84.0*Xb0_rev_c_3 + 96.0*Xb0_rev_c_4 + 96.0*Xb0_rev_c_5 + 90.0*Xb0_rev_c_6 + 138.0*Xb0_rev_c_7 + 90.0*Xb0_rev_c_8 + 132.0*Xb0_rev_c_9 + 169803000.0*Yc_0 + 94335000.0*Yc_1 + 113202000.0*Yc_10 + 150936000.0*Yc_11 + 169803000.0*Yc_12 + 122635500.0*Yc_13 + 66034500.0*Yc_14 + 150936000.0*Yc_2 + 169803000.0*Yc_3 + 103768500.0*Yc_4 + 160369500.0*Yc_5 + 188670000.0*Yc_6 + 84901500.0*Yc_7 + 122635500.0*Yc_8 + 103768500.0*Yc_9 + 0.0}

# %%
cons
# Out:
# {0: 1*Xb0_rev_c_0 + -360.0*Yc_0 + 0.0 >= 0,
#  1: 1*Xb0_rev_c_1 + -200.0*Yc_1 + 0.0 >= 0,
#  2: 1*Xb0_rev_c_2 + -320.0*Yc_2 + 0.0 >= 0,
#  3: 1*Xb0_rev_c_3 + -360.0*Yc_3 + 0.0 >= 0,
#  4: 1*Xb0_rev_c_4 + -220.0*Yc_4 + 0.0 >= 0,
#  5: 1*Xb0_rev_c_5 + -340.0*Yc_5 + 0.0 >= 0,
#  6: 1*Xb0_rev_c_6 + -400.0*Yc_6 + 0.0 >= 0,
#  7: 1*Xb0_rev_c_7 + -180.0*Yc_7 + 0.0 >= 0,
#  8: 1*Xb0_rev_c_8 + -260.0*Yc_8 + 0.0 >= 0,
#  9: 1*Xb0_rev_c_9 + -220.0*Yc_9 + 0.0 >= 0,
#  10: 1*Xb0_rev_c_10 + -240.0*Yc_10 + 0.0 >= 0,
#  11: 1*Xb0_rev_c_11 + -320.0*Yc_11 + 0.0 >= 0,
#  12: 1*Xb0_rev_c_12 + -360.0*Yc_12 + 0.0 >= 0,
#  13: 1*Xb0_rev_c_13 + -260.0*Yc_13 + 0.0 >= 0,
#  14: 1*Xb0_rev_c_14 + -140.0*Yc_14 + 0.0 >= 0,
#  15: -2e-05*Xb0_c_0 + 1*Yb_0 + 0.0 >= 0,
#  16: -2e-05*Xb0_rev_c_0 + 1*Yb_0 + 0.0 >= 0,
#  17: -2e-05*Xb0_c_1 + 1*Yb_0 + 0.0 >= 0,
#  18: -2e-05*Xb0_rev_c_1 + 1*Yb_0 + 0.0 >= 0,
#  19: -2e-05*Xb0_c_2 + 1*Yb_0 + 0.0 >= 0,
#  20: -2e-05*Xb0_rev_c_2 + 1*Yb_0 + 0.0 >= 0,
#  21: -2e-05*Xb0_c_3 + 1*Yb_0 + 0.0 >= 0,
#  22: -2e-05*Xb0_rev_c_3 + 1*Yb_0 + 0.0 >= 0,
#  23: -2e-05*Xb0_c_4 + 1*Yb_0 + 0.0 >= 0,
#  24: -2e-05*Xb0_rev_c_4 + 1*Yb_0 + 0.0 >= 0,
#  25: -2e-05*Xb0_c_5 + 1*Yb_0 + 0.0 >= 0,
#  26: -2e-05*Xb0_rev_c_5 + 1*Yb_0 + 0.0 >= 0,
#  27: -2e-05*Xb0_c_6 + 1*Yb_0 + 0.0 >= 0,
#  28: -2e-05*Xb0_rev_c_6 + 1*Yb_0 + 0.0 >= 0,
#  29: -2e-05*Xb0_c_7 + 1*Yb_0 + 0.0 >= 0,
#  30: -2e-05*Xb0_rev_c_7 + 1*Yb_0 + 0.0 >= 0,
#  31: -2e-05*Xb0_c_8 + 1*Yb_0 + 0.0 >= 0,
#  32: -2e-05*Xb0_rev_c_8 + 1*Yb_0 + 0.0 >= 0,
#  33: -2e-05*Xb0_c_9 + 1*Yb_0 + 0.0 >= 0,
#  34: -2e-05*Xb0_rev_c_9 + 1*Yb_0 + 0.0 >= 0,
#  35: -2e-05*Xb0_c_10 + 1*Yb_0 + 0.0 >= 0,
#  36: -2e-05*Xb0_rev_c_10 + 1*Yb_0 + 0.0 >= 0,
#  37: -2e-05*Xb0_c_11 + 1*Yb_0 + 0.0 >= 0,
#  38: -2e-05*Xb0_rev_c_11 + 1*Yb_0 + 0.0 >= 0,
#  39: -2e-05*Xb0_c_12 + 1*Yb_0 + 0.0 >= 0,
#  40: -2e-05*Xb0_rev_c_12 + 1*Yb_0 + 0.0 >= 0,
#  41: -2e-05*Xb0_c_13 + 1*Yb_0 + 0.0 >= 0,
#  42: -2e-05*Xb0_rev_c_13 + 1*Yb_0 + 0.0 >= 0,
#  43: -2e-05*Xb0_c_14 + 1*Yb_0 + 0.0 >= 0,
#  44: -2e-05*Xb0_rev_c_14 + 1*Yb_0 + 0.0 >= 0,
#  45: -1*Xb0_rev_c_0 + -1*Xb0_rev_c_1 + -1*Xb0_rev_c_10 + -1*Xb0_rev_c_11 + -1*Xb0_rev_c_12 + -1*Xb0_rev_c_13 + -1*Xb0_rev_c_14 + -1*Xb0_rev_c_2 + -1*Xb0_rev_c_3 + -1*Xb0_rev_c_4 + -1*Xb0_rev_c_5 + -1*Xb0_rev_c_6 + -1*Xb0_rev_c_7 + -1*Xb0_rev_c_8 + -1*Xb0_rev_c_9 + 1*Xdb_0 + 0 = 0,
#  46: 1*Xb0_c_0 + -1*Xb0_rev_c_0 + -240000*Yc_0 + 0 <= 0,
#  47: 1*Xb0_c_0 + -1*Xb0_rev_c_0 + 0 >= 0,
#  48: 1*Xb0_c_1 + -1*Xb0_rev_c_1 + -96000*Yc_1 + 0 <= 0,
#  49: 1*Xb0_c_1 + -1*Xb0_rev_c_1 + 0 >= 0,
#  50: 1*Xb0_c_2 + -1*Xb0_rev_c_2 + -324000*Yc_2 + 0 <= 0,
#  51: 1*Xb0_c_2 + -1*Xb0_rev_c_2 + 0 >= 0,
#  52: 1*Xb0_c_3 + -1*Xb0_rev_c_3 + -144000*Yc_3 + 0 <= 0,
#  53: 1*Xb0_c_3 + -1*Xb0_rev_c_3 + 0 >= 0,
#  54: 1*Xb0_c_4 + -1*Xb0_rev_c_4 + -96000*Yc_4 + 0 <= 0,
#  55: 1*Xb0_c_4 + -1*Xb0_rev_c_4 + 0 >= 0,
#  56: 1*Xb0_c_5 + -1*Xb0_rev_c_5 + -288000*Yc_5 + 0 <= 0,
#  57: 1*Xb0_c_5 + -1*Xb0_rev_c_5 + 0 >= 0,
#  58: 1*Xb0_c_6 + -1*Xb0_rev_c_6 + -384000*Yc_6 + 0 <= 0,
#  59: 1*Xb0_c_6 + -1*Xb0_rev_c_6 + 0 >= 0,
#  60: 1*Xb0_c_7 + -1*Xb0_rev_c_7 + -180000*Yc_7 + 0 <= 0,
#  61: 1*Xb0_c_7 + -1*Xb0_rev_c_7 + 0 >= 0,
#  62: 1*Xb0_c_8 + -1*Xb0_rev_c_8 + -264000*Yc_8 + 0 <= 0,
#  63: 1*Xb0_c_8 + -1*Xb0_rev_c_8 + 0 >= 0,
#  64: 1*Xb0_c_9 + -1*Xb0_rev_c_9 + -324000*Yc_9 + 0 <= 0,
#  65: 1*Xb0_c_9 + -1*Xb0_rev_c_9 + 0 >= 0,
#  66: 1*Xb0_c_10 + -1*Xb0_rev_c_10 + -288000*Yc_10 + 0 <= 0,
#  67: 1*Xb0_c_10 + -1*Xb0_rev_c_10 + 0 >= 0,
#  68: 1*Xb0_c_11 + -1*Xb0_rev_c_11 + -120000*Yc_11 + 0 <= 0,
#  69: 1*Xb0_c_11 + -1*Xb0_rev_c_11 + 0 >= 0,
#  70: 1*Xb0_c_12 + -1*Xb0_rev_c_12 + -96000*Yc_12 + 0 <= 0,
#  71: 1*Xb0_c_12 + -1*Xb0_rev_c_12 + 0 >= 0,
#  72: 1*Xb0_c_13 + -1*Xb0_rev_c_13 + -384000*Yc_13 + 0 <= 0,
#  73: 1*Xb0_c_13 + -1*Xb0_rev_c_13 + 0 >= 0,
#  74: 1*Xb0_c_14 + -1*Xb0_rev_c_14 + -324000*Yc_14 + 0 <= 0,
#  75: 1*Xb0_c_14 + -1*Xb0_rev_c_14 + 0 >= 0,
#  76: 1*Xab_0 + -1*Xb0_c_0 + 1*Xb0_rev_c_0 + -1*Xdb_0 + -13500000*Yb_0 + 0 <= 0,
#  77: 1*Xab_0 + -1*Xb0_c_0 + 1*Xb0_rev_c_0 + -1*Xdb_0 + 0 >= 0,
#  78: 18000*Yc_0 + 10000*Yc_1 + 12000*Yc_10 + 16000*Yc_11 + 18000*Yc_12 + 13000*Yc_13 + 7000*Yc_14 + 16000*Yc_2 + 18000*Yc_3 + 11000*Yc_4 + 17000*Yc_5 + 20000*Yc_6 + 9000*Yc_7 + 13000*Yc_8 + 11000*Yc_9 + -140000 >= 0,
#  79: 1*Yc_0 + 1*Yc_1 + 1*Yc_10 + 1*Yc_11 + 1*Yc_12 + 1*Yc_13 + 1*Yc_14 + 1*Yc_2 + 1*Yc_3 + 1*Yc_4 + 1*Yc_5 + 1*Yc_6 + 1*Yc_7 + 1*Yc_8 + 1*Yc_9 + -6 >= 0}

# %% [markdown]
# ### Payoff table

# %%
payoff=np.zeros([len(obj),len(obj)]);
for k in range(0,len(obj)):
    model = LpProblem("Min",LpMinimize)
    model += obj[k]
    for i in range(0,len(cons)):
        model += cons[i]
    result = model.solve()
    if LpStatus[result] == 'Optimal':
        
        payoff[k,k]= value(model.objective);
        kp=k+1;
        model = LpProblem("Min",LpMinimize)
        while kp<= len(obj)-1:
                model += obj[kp]
                if kp-1>=0:
                    model += obj[kp-1] <= payoff[k,kp-1]
                for i in range(0,len(cons)):
                    model += cons[i]
                result = model.solve()
                if LpStatus[result] == 'Optimal':
                    
                    payoff[k,kp]= value(model.objective)
                    kp += 1     
                else:
                    sys.exit('no optimal solution for mod_payoff')
        kp=0;
        model += obj[k] <= payoff[k,k]
        while kp< k:
            model += obj[kp]
            if kp-1>=0:
                model += obj[kp-1] <= payoff[k,kp-1]
            for i in range(0,len(cons)):
                model += cons[i]
            result = model.solve()
            if LpStatus[result] == 'Optimal':
                
                payoff[k,kp]= value(model.objective)
                kp += 1
            else:
                sys.exit('no optimal solution for mod_payoff')   
           
    else:
        sys.exit('no optimal solution for mod_payoff')

# %%
payoff
# Out:
# array([[1.23141920e+07, 1.32258312e+09],
#        [1.30002320e+07, 1.32252336e+09]])

# %%
minobj=np.zeros([len(obj),1]);
maxobj=np.zeros([len(obj),1]);
for k in range(0,len(obj)):
        minobj[k] = min(payoff[:,k]);
        maxobj[k] = max(payoff[:,k]);

# %%
minobj
# Out:
# array([[1.23141920e+07],
#        [1.32252336e+09]])

# %%
maxobj
# Out:
# array([[1.30002320e+07],
#        [1.32258312e+09]])

# %% [markdown]
# ### pareto optimal solution

# %%
# slack variables
s = {
     1: LpVariable("s2",lowBound = 0),
     }

# %%
intervals=5;
grid_points=[]
lst = np.empty([intervals+1,len(obj)]);
key_intervals ={}
for g in range(0,intervals+1):
    print('grid point no: ', g+1, 'val: ', maxobj[1] - ((g)/intervals)*(maxobj[1]- minobj[1]))
    grid_points.append(maxobj[1] - ((g)/intervals)*(maxobj[1]- minobj[1]))
    model = LpProblem("Min",LpMinimize)
    code = 1/(maxobj[1]-minobj[1]);
    model += obj[0]+1e-3*s[1]*code
    model += obj[1]+s[1] == maxobj[1] - ((g)/intervals)*(maxobj[1]- minobj[1])
    for i in range(0,len(cons)):
        model += cons[i]
    print(model)
    result = model.solve()
    if LpStatus[result] == 'Optimal':
        key_variable = {}
        for variables in model.variables():
            key_variable[variables]=variables.value()
        key_intervals[g]=key_variable
        for k in range(0,len(obj)):
            if k==0:
                var_coef = dict(zip(list(prob.objective.keys()),list(prob.objective.values())))
                lst[g,k]=sum(k.value()*v  for k,v in var_coef.items())
            if k==1:
                var_coeff = dict(zip(list(prob2.objective.keys()),list(prob2.objective.values())))
                lst[g,k]=sum(k.value()*v  for k,v in var_coeff.items())
    else:
        print('early exit (jump)')
        break
# Out:
# grid point no:  1 val:  [1.32258312e+09]
# Min:
# MINIMIZE
# 26.64*Xab_0 + 8.0*Xb0_c_0 + 9.0*Xb0_c_1 + 21.0*Xb0_c_10 + 26.0*Xb0_c_11 + 16.0*Xb0_c_12 + 12.0*Xb0_c_13 + 18.0*Xb0_c_14 + 13.0*Xb0_c_2 + 14.0*Xb0_c_3 + 16.0*Xb0_c_4 + 16.0*Xb0_c_5 + 15.0*Xb0_c_6 + 23.0*Xb0_c_7 + 15.0*Xb0_c_8 + 22.0*Xb0_c_9 + 8.0*Xb0_rev_c_0 + 9.0*Xb0_rev_c_1 + 21.0*Xb0_rev_c_10 + 26.0*Xb0_rev_c_11 + 16.0*Xb0_rev_c_12 + 12.0*Xb0_rev_c_13 + 18.0*Xb0_rev_c_14 + 13.0*Xb0_rev_c_2 + 14.0*Xb0_rev_c_3 + 16.0*Xb0_rev_c_4 + 16.0*Xb0_rev_c_5 + 15.0*Xb0_rev_c_6 + 23.0*Xb0_rev_c_7 + 15.0*Xb0_rev_c_8 + 22.0*Xb0_rev_c_9 + 400*Xdb_0 + 5500000*Yb_0 + 726000.0*Yc_0 + 366000.0*Yc_1 + 612000.0*Yc_10 + 552000.0*Yc_11 + 582000.0*Yc_12 + 735000.0*Yc_13 + 513000.0*Yc_14 + 756000.0*Yc_2 + 630000.0*Yc_3 + 393000.0*Yc_4 + 747000.0*Yc_5 + 924000.0*Yc_6 + 423000.0*Yc_7 + 615000.0*Yc_8 + 621000.0*Yc_9 + [1.67336011e-08]*s2 + [0.]
# SUBJECT TO
# _C1: 488.4 Xab_0 + 48 Xb0_c_0 + 54 Xb0_c_1 + 126 Xb0_c_10 + 156 Xb0_c_11
#  + 96 Xb0_c_12 + 72 Xb0_c_13 + 108 Xb0_c_14 + 78 Xb0_c_2 + 84 Xb0_c_3
#  + 96 Xb0_c_4 + 96 Xb0_c_5 + 90 Xb0_c_6 + 138 Xb0_c_7 + 90 Xb0_c_8
#  + 132 Xb0_c_9 + 48 Xb0_rev_c_0 + 54 Xb0_rev_c_1 + 126 Xb0_rev_c_10
#  + 156 Xb0_rev_c_11 + 96 Xb0_rev_c_12 + 72 Xb0_rev_c_13 + 108 Xb0_rev_c_14
#  + 78 Xb0_rev_c_2 + 84 Xb0_rev_c_3 + 96 Xb0_rev_c_4 + 96 Xb0_rev_c_5
#  + 90 Xb0_rev_c_6 + 138 Xb0_rev_c_7 + 90 Xb0_rev_c_8 + 132 Xb0_rev_c_9
#  + 169803000 Yc_0 + 94335000 Yc_1 + 113202000 Yc_10 + 150936000 Yc_11
#  + 169803000 Yc_12 + 122635500 Yc_13 + 66034500 Yc_14 + 150936000 Yc_2
#  + 169803000 Yc_3 + 103768500 Yc_4 + 160369500 Yc_5 + 188670000 Yc_6
#  + 84901500 Yc_7 + 122635500 Yc_8 + 103768500 Yc_9 + s2 = 1322583120
#
# _C2: Xb0_rev_c_0 - 360 Yc_0 >= 0
#
# _C3: Xb0_rev_c_1 - 200 Yc_1 >= 0
#
# _C4: Xb0_rev_c_2 - 320 Yc_2 >= 0
#
# _C5: Xb0_rev_c_3 - 360 Yc_3 >= 0
#
# _C6: Xb0_rev_c_4 - 220 Yc_4 >= 0
#
# _C7: Xb0_rev_c_5 - 340 Yc_5 >= 0
#
# _C8: Xb0_rev_c_6 - 400 Yc_6 >= 0
#
# _C9: Xb0_rev_c_7 - 180 Yc_7 >= 0
#
# _C10: Xb0_rev_c_8 - 260 Yc_8 >= 0
#
# _C11: Xb0_rev_c_9 - 220 Yc_9 >= 0
#
# _C12: Xb0_rev_c_10 - 240 Yc_10 >= 0
#
# _C13: Xb0_rev_c_11 - 320 Yc_11 >= 0
#
# _C14: Xb0_rev_c_12 - 360 Yc_12 >= 0
#
# _C15: Xb0_rev_c_13 - 260 Yc_13 >= 0
#
# _C16: Xb0_rev_c_14 - 140 Yc_14 >= 0
#
# _C17: - 2e-05 Xb0_c_0 + Yb_0 >= 0
#
# _C18: - 2e-05 Xb0_rev_c_0 + Yb_0 >= 0
#
# _C19: - 2e-05 Xb0_c_1 + Yb_0 >= 0
#
# _C20: - 2e-05 Xb0_rev_c_1 + Yb_0 >= 0
#
# _C21: - 2e-05 Xb0_c_2 + Yb_0 >= 0
#
# _C22: - 2e-05 Xb0_rev_c_2 + Yb_0 >= 0
#
# _C23: - 2e-05 Xb0_c_3 + Yb_0 >= 0
#
# _C24: - 2e-05 Xb0_rev_c_3 + Yb_0 >= 0
#
# _C25: - 2e-05 Xb0_c_4 + Yb_0 >= 0
#
# _C26: - 2e-05 Xb0_rev_c_4 + Yb_0 >= 0
#
# _C27: - 2e-05 Xb0_c_5 + Yb_0 >= 0
#
# _C28: - 2e-05 Xb0_rev_c_5 + Yb_0 >= 0
#
# _C29: - 2e-05 Xb0_c_6 + Yb_0 >= 0
#
# _C30: - 2e-05 Xb0_rev_c_6 + Yb_0 >= 0
#
# _C31: - 2e-05 Xb0_c_7 + Yb_0 >= 0
#
# _C32: - 2e-05 Xb0_rev_c_7 + Yb_0 >= 0
#
# _C33: - 2e-05 Xb0_c_8 + Yb_0 >= 0
#
# _C34: - 2e-05 Xb0_rev_c_8 + Yb_0 >= 0
#
# _C35: - 2e-05 Xb0_c_9 + Yb_0 >= 0
#
# _C36: - 2e-05 Xb0_rev_c_9 + Yb_0 >= 0
#
# _C37: - 2e-05 Xb0_c_10 + Yb_0 >= 0
#
# _C38: - 2e-05 Xb0_rev_c_10 + Yb_0 >= 0
#
# _C39: - 2e-05 Xb0_c_11 + Yb_0 >= 0
#
# _C40: - 2e-05 Xb0_rev_c_11 + Yb_0 >= 0
#
# _C41: - 2e-05 Xb0_c_12 + Yb_0 >= 0
#
# _C42: - 2e-05 Xb0_rev_c_12 + Yb_0 >= 0
#
# _C43: - 2e-05 Xb0_c_13 + Yb_0 >= 0
#
# _C44: - 2e-05 Xb0_rev_c_13 + Yb_0 >= 0
#
# _C45: - 2e-05 Xb0_c_14 + Yb_0 >= 0
#
# _C46: - 2e-05 Xb0_rev_c_14 + Yb_0 >= 0
#
# _C47: - Xb0_rev_c_0 - Xb0_rev_c_1 - Xb0_rev_c_10 - Xb0_rev_c_11 - Xb0_rev_c_12
#  - Xb0_rev_c_13 - Xb0_rev_c_14 - Xb0_rev_c_2 - Xb0_rev_c_3 - Xb0_rev_c_4
#  - Xb0_rev_c_5 - Xb0_rev_c_6 - Xb0_rev_c_7 - Xb0_rev_c_8 - Xb0_rev_c_9 + Xdb_0
#  = 0
#
# _C48: Xb0_c_0 - Xb0_rev_c_0 - 240000 Yc_0 <= 0
#
# _C49: Xb0_c_0 - Xb0_rev_c_0 >= 0
#
# _C50: Xb0_c_1 - Xb0_rev_c_1 - 96000 Yc_1 <= 0
#
# _C51: Xb0_c_1 - Xb0_rev_c_1 >= 0
#
# _C52: Xb0_c_2 - Xb0_rev_c_2 - 324000 Yc_2 <= 0
#
# _C53: Xb0_c_2 - Xb0_rev_c_2 >= 0
#
# _C54: Xb0_c_3 - Xb0_rev_c_3 - 144000 Yc_3 <= 0
#
# _C55: Xb0_c_3 - Xb0_rev_c_3 >= 0
#
# _C56: Xb0_c_4 - Xb0_rev_c_4 - 96000 Yc_4 <= 0
#
# _C57: Xb0_c_4 - Xb0_rev_c_4 >= 0
#
# _C58: Xb0_c_5 - Xb0_rev_c_5 - 288000 Yc_5 <= 0
#
# _C59: Xb0_c_5 - Xb0_rev_c_5 >= 0
#
# _C60: Xb0_c_6 - Xb0_rev_c_6 - 384000 Yc_6 <= 0
#
# _C61: Xb0_c_6 - Xb0_rev_c_6 >= 0
#
# _C62: Xb0_c_7 - Xb0_rev_c_7 - 180000 Yc_7 <= 0
#
# _C63: Xb0_c_7 - Xb0_rev_c_7 >= 0
#
# _C64: Xb0_c_8 - Xb0_rev_c_8 - 264000 Yc_8 <= 0
#
# _C65: Xb0_c_8 - Xb0_rev_c_8 >= 0
#
# _C66: Xb0_c_9 - Xb0_rev_c_9 - 324000 Yc_9 <= 0
#
# _C67: Xb0_c_9 - Xb0_rev_c_9 >= 0
#
# _C68: Xb0_c_10 - Xb0_rev_c_10 - 288000 Yc_10 <= 0
#
# _C69: Xb0_c_10 - Xb0_rev_c_10 >= 0
#
# _C70: Xb0_c_11 - Xb0_rev_c_11 - 120000 Yc_11 <= 0
#
# _C71: Xb0_c_11 - Xb0_rev_c_11 >= 0
#
# _C72: Xb0_c_12 - Xb0_rev_c_12 - 96000 Yc_12 <= 0
#
# _C73: Xb0_c_12 - Xb0_rev_c_12 >= 0
#
# _C74: Xb0_c_13 - Xb0_rev_c_13 - 384000 Yc_13 <= 0
#
# _C75: Xb0_c_13 - Xb0_rev_c_13 >= 0
#
# _C76: Xb0_c_14 - Xb0_rev_c_14 - 324000 Yc_14 <= 0
#
# _C77: Xb0_c_14 - Xb0_rev_c_14 >= 0
#
# _C78: Xab_0 - Xb0_c_0 + Xb0_rev_c_0 - Xdb_0 - 13500000 Yb_0 <= 0
#
# _C79: Xab_0 - Xb0_c_0 + Xb0_rev_c_0 - Xdb_0 >= 0
#
# _C80: 18000 Yc_0 + 10000 Yc_1 + 12000 Yc_10 + 16000 Yc_11 + 18000 Yc_12
#  + 13000 Yc_13 + 7000 Yc_14 + 16000 Yc_2 + 18000 Yc_3 + 11000 Yc_4
#  + 17000 Yc_5 + 20000 Yc_6 + 9000 Yc_7 + 13000 Yc_8 + 11000 Yc_9 >= 140000
#
# _C81: Yc_0 + Yc_1 + Yc_10 + Yc_11 + Yc_12 + Yc_13 + Yc_14 + Yc_2 + Yc_3 + Yc_4
#  + Yc_5 + Yc_6 + Yc_7 + Yc_8 + Yc_9 >= 6
#
# VARIABLES
# 0 <= Xab_0 Integer
# 0 <= Xb0_c_0 Integer
# 0 <= Xb0_c_1 Integer
# 0 <= Xb0_c_10 Integer
# 0 <= Xb0_c_11 Integer
# 0 <= Xb0_c_12 Integer
# 0 <= Xb0_c_13 Integer
# 0 <= Xb0_c_14 Integer
# 0 <= Xb0_c_2 Integer
# 0 <= Xb0_c_3 Integer
# 0 <= Xb0_c_4 Integer
# 0 <= Xb0_c_5 Integer
# 0 <= Xb0_c_6 Integer
# 0 <= Xb0_c_7 Integer
# 0 <= Xb0_c_8 Integer
# 0 <= Xb0_c_9 Integer
# 0 <= Xb0_rev_c_0 Integer
# 0 <= Xb0_rev_c_1 Integer
# 0 <= Xb0_rev_c_10 Integer
# 0 <= Xb0_rev_c_11 Integer
# 0 <= Xb0_rev_c_12 Integer
# 0 <= Xb0_rev_c_13 Integer
# 0 <= Xb0_rev_c_14 Integer
# 0 <= Xb0_rev_c_2 Integer
# 0 <= Xb0_rev_c_3 Integer
# 0 <= Xb0_rev_c_4 Integer
# 0 <= Xb0_rev_c_5 Integer
# 0 <= Xb0_rev_c_6 Integer
# 0 <= Xb0_rev_c_7 Integer
# 0 <= Xb0_rev_c_8 Integer
# 0 <= Xb0_rev_c_9 Integer
# 0 <= Xdb_0 Integer
# 0 <= Yb_0 <= 1 Integer
# 0 <= Yc_0 <= 1 Integer
# 0 <= Yc_1 <= 1 Integer
# 0 <= Yc_10 <= 1 Integer
# 0 <= Yc_11 <= 1 Integer
# 0 <= Yc_12 <= 1 Integer
# 0 <= Yc_13 <= 1 Integer
# 0 <= Yc_14 <= 1 Integer
# 0 <= Yc_2 <= 1 Integer
# 0 <= Yc_3 <= 1 Integer
# 0 <= Yc_4 <= 1 Integer
# 0 <= Yc_5 <= 1 Integer
# 0 <= Yc_6 <= 1 Integer
# 0 <= Yc_7 <= 1 Integer
# 0 <= Yc_8 <= 1 Integer
# 0 <= Yc_9 <= 1 Integer
# s2 Continuous
#
# grid point no:  2 val:  [1.32257117e+09]
# Min:
# MINIMIZE
# 26.64*Xab_0 + 8.0*Xb0_c_0 + 9.0*Xb0_c_1 + 21.0*Xb0_c_10 + 26.0*Xb0_c_11 + 16.0*Xb0_c_12 + 12.0*Xb0_c_13 + 18.0*Xb0_c_14 + 13.0*Xb0_c_2 + 14.0*Xb0_c_3 + 16.0*Xb0_c_4 + 16.0*Xb0_c_5 + 15.0*Xb0_c_6 + 23.0*Xb0_c_7 + 15.0*Xb0_c_8 + 22.0*Xb0_c_9 + 8.0*Xb0_rev_c_0 + 9.0*Xb0_rev_c_1 + 21.0*Xb0_rev_c_10 + 26.0*Xb0_rev_c_11 + 16.0*Xb0_rev_c_12 + 12.0*Xb0_rev_c_13 + 18.0*Xb0_rev_c_14 + 13.0*Xb0_rev_c_2 + 14.0*Xb0_rev_c_3 + 16.0*Xb0_rev_c_4 + 16.0*Xb0_rev_c_5 + 15.0*Xb0_rev_c_6 + 23.0*Xb0_rev_c_7 + 15.0*Xb0_rev_c_8 + 22.0*Xb0_rev_c_9 + 400*Xdb_0 + 5500000*Yb_0 + 726000.0*Yc_0 + 366000.0*Yc_1 + 612000.0*Yc_10 + 552000.0*Yc_11 + 582000.0*Yc_12 + 735000.0*Yc_13 + 513000.0*Yc_14 + 756000.0*Yc_2 + 630000.0*Yc_3 + 393000.0*Yc_4 + 747000.0*Yc_5 + 924000.0*Yc_6 + 423000.0*Yc_7 + 615000.0*Yc_8 + 621000.0*Yc_9 + [1.67336011e-08]*s2 + [0.]
# SUBJECT TO
# _C1: 488.4 Xab_0 + 48 Xb0_c_0 + 54 Xb0_c_1 + 126 Xb0_c_10 + 156 Xb0_c_11
#  + 96 Xb0_c_12 + 72 Xb0_c_13 + 108 Xb0_c_14 + 78 Xb0_c_2 + 84 Xb0_c_3
#  + 96 Xb0_c_4 + 96 Xb0_c_5 + 90 Xb0_c_6 + 138 Xb0_c_7 + 90 Xb0_c_8
#  + 132 Xb0_c_9 + 48 Xb0_rev_c_0 + 54 Xb0_rev_c_1 + 126 Xb0_rev_c_10
#  + 156 Xb0_rev_c_11 + 96 Xb0_rev_c_12 + 72 Xb0_rev_c_13 + 108 Xb0_rev_c_14
#  + 78 Xb0_rev_c_2 + 84 Xb0_rev_c_3 + 96 Xb0_rev_c_4 + 96 Xb0_rev_c_5
#  + 90 Xb0_rev_c_6 + 138 Xb0_rev_c_7 + 90 Xb0_rev_c_8 + 132 Xb0_rev_c_9
#  + 169803000 Yc_0 + 94335000 Yc_1 + 113202000 Yc_10 + 150936000 Yc_11
#  + 169803000 Yc_12 + 122635500 Yc_13 + 66034500 Yc_14 + 150936000 Yc_2
#  + 169803000 Yc_3 + 103768500 Yc_4 + 160369500 Yc_5 + 188670000 Yc_6
#  + 84901500 Yc_7 + 122635500 Yc_8 + 103768500 Yc_9 + s2 = 1322571168
#
# _C2: Xb0_rev_c_0 - 360 Yc_0 >= 0
#
# _C3: Xb0_rev_c_1 - 200 Yc_1 >= 0
#
# _C4: Xb0_rev_c_2 - 320 Yc_2 >= 0
#
# _C5: Xb0_rev_c_3 - 360 Yc_3 >= 0
#
# _C6: Xb0_rev_c_4 - 220 Yc_4 >= 0
#
# _C7: Xb0_rev_c_5 - 340 Yc_5 >= 0
#
# _C8: Xb0_rev_c_6 - 400 Yc_6 >= 0
#
# _C9: Xb0_rev_c_7 - 180 Yc_7 >= 0
#
# _C10: Xb0_rev_c_8 - 260 Yc_8 >= 0
#
# _C11: Xb0_rev_c_9 - 220 Yc_9 >= 0
#
# _C12: Xb0_rev_c_10 - 240 Yc_10 >= 0
#
# _C13: Xb0_rev_c_11 - 320 Yc_11 >= 0
#
# _C14: Xb0_rev_c_12 - 360 Yc_12 >= 0
#
# _C15: Xb0_rev_c_13 - 260 Yc_13 >= 0
#
# _C16: Xb0_rev_c_14 - 140 Yc_14 >= 0
#
# _C17: - 2e-05 Xb0_c_0 + Yb_0 >= 0
#
# _C18: - 2e-05 Xb0_rev_c_0 + Yb_0 >= 0
#
# _C19: - 2e-05 Xb0_c_1 + Yb_0 >= 0
#
# _C20: - 2e-05 Xb0_rev_c_1 + Yb_0 >= 0
#
# _C21: - 2e-05 Xb0_c_2 + Yb_0 >= 0
#
# _C22: - 2e-05 Xb0_rev_c_2 + Yb_0 >= 0
#
# _C23: - 2e-05 Xb0_c_3 + Yb_0 >= 0
#
# _C24: - 2e-05 Xb0_rev_c_3 + Yb_0 >= 0
#
# _C25: - 2e-05 Xb0_c_4 + Yb_0 >= 0
#
# _C26: - 2e-05 Xb0_rev_c_4 + Yb_0 >= 0
#
# _C27: - 2e-05 Xb0_c_5 + Yb_0 >= 0
#
# _C28: - 2e-05 Xb0_rev_c_5 + Yb_0 >= 0
#
# _C29: - 2e-05 Xb0_c_6 + Yb_0 >= 0
#
# _C30: - 2e-05 Xb0_rev_c_6 + Yb_0 >= 0
#
# _C31: - 2e-05 Xb0_c_7 + Yb_0 >= 0
#
# _C32: - 2e-05 Xb0_rev_c_7 + Yb_0 >= 0
#
# _C33: - 2e-05 Xb0_c_8 + Yb_0 >= 0
#
# _C34: - 2e-05 Xb0_rev_c_8 + Yb_0 >= 0
#
# _C35: - 2e-05 Xb0_c_9 + Yb_0 >= 0
#
# _C36: - 2e-05 Xb0_rev_c_9 + Yb_0 >= 0
#
# _C37: - 2e-05 Xb0_c_10 + Yb_0 >= 0
#
# _C38: - 2e-05 Xb0_rev_c_10 + Yb_0 >= 0
#
# _C39: - 2e-05 Xb0_c_11 + Yb_0 >= 0
#
# _C40: - 2e-05 Xb0_rev_c_11 + Yb_0 >= 0
#
# _C41: - 2e-05 Xb0_c_12 + Yb_0 >= 0
#
# _C42: - 2e-05 Xb0_rev_c_12 + Yb_0 >= 0
#
# _C43: - 2e-05 Xb0_c_13 + Yb_0 >= 0
#
# _C44: - 2e-05 Xb0_rev_c_13 + Yb_0 >= 0
#
# _C45: - 2e-05 Xb0_c_14 + Yb_0 >= 0
#
# _C46: - 2e-05 Xb0_rev_c_14 + Yb_0 >= 0
#
# _C47: - Xb0_rev_c_0 - Xb0_rev_c_1 - Xb0_rev_c_10 - Xb0_rev_c_11 - Xb0_rev_c_12
#  - Xb0_rev_c_13 - Xb0_rev_c_14 - Xb0_rev_c_2 - Xb0_rev_c_3 - Xb0_rev_c_4
#  - Xb0_rev_c_5 - Xb0_rev_c_6 - Xb0_rev_c_7 - Xb0_rev_c_8 - Xb0_rev_c_9 + Xdb_0
#  = 0
#
# _C48: Xb0_c_0 - Xb0_rev_c_0 - 240000 Yc_0 <= 0
#
# _C49: Xb0_c_0 - Xb0_rev_c_0 >= 0
#
# _C50: Xb0_c_1 - Xb0_rev_c_1 - 96000 Yc_1 <= 0
#
# _C51: Xb0_c_1 - Xb0_rev_c_1 >= 0
#
# _C52: Xb0_c_2 - Xb0_rev_c_2 - 324000 Yc_2 <= 0
#
# _C53: Xb0_c_2 - Xb0_rev_c_2 >= 0
#
# _C54: Xb0_c_3 - Xb0_rev_c_3 - 144000 Yc_3 <= 0
#
# _C55: Xb0_c_3 - Xb0_rev_c_3 >= 0
#
# _C56: Xb0_c_4 - Xb0_rev_c_4 - 96000 Yc_4 <= 0
#
# _C57: Xb0_c_4 - Xb0_rev_c_4 >= 0
#
# _C58: Xb0_c_5 - Xb0_rev_c_5 - 288000 Yc_5 <= 0
#
# _C59: Xb0_c_5 - Xb0_rev_c_5 >= 0
#
# _C60: Xb0_c_6 - Xb0_rev_c_6 - 384000 Yc_6 <= 0
#
# _C61: Xb0_c_6 - Xb0_rev_c_6 >= 0
#
# _C62: Xb0_c_7 - Xb0_rev_c_7 - 180000 Yc_7 <= 0
#
# _C63: Xb0_c_7 - Xb0_rev_c_7 >= 0
#
# _C64: Xb0_c_8 - Xb0_rev_c_8 - 264000 Yc_8 <= 0
#
# _C65: Xb0_c_8 - Xb0_rev_c_8 >= 0
#
# _C66: Xb0_c_9 - Xb0_rev_c_9 - 324000 Yc_9 <= 0
#
# _C67: Xb0_c_9 - Xb0_rev_c_9 >= 0
#
# _C68: Xb0_c_10 - Xb0_rev_c_10 - 288000 Yc_10 <= 0
#
# _C69: Xb0_c_10 - Xb0_rev_c_10 >= 0
#
# _C70: Xb0_c_11 - Xb0_rev_c_11 - 120000 Yc_11 <= 0
#
# _C71: Xb0_c_11 - Xb0_rev_c_11 >= 0
#
# _C72: Xb0_c_12 - Xb0_rev_c_12 - 96000 Yc_12 <= 0
#
# _C73: Xb0_c_12 - Xb0_rev_c_12 >= 0
#
# _C74: Xb0_c_13 - Xb0_rev_c_13 - 384000 Yc_13 <= 0
#
# _C75: Xb0_c_13 - Xb0_rev_c_13 >= 0
#
# _C76: Xb0_c_14 - Xb0_rev_c_14 - 324000 Yc_14 <= 0
#
# _C77: Xb0_c_14 - Xb0_rev_c_14 >= 0
#
# _C78: Xab_0 - Xb0_c_0 + Xb0_rev_c_0 - Xdb_0 - 13500000 Yb_0 <= 0
#
# _C79: Xab_0 - Xb0_c_0 + Xb0_rev_c_0 - Xdb_0 >= 0
#
# _C80: 18000 Yc_0 + 10000 Yc_1 + 12000 Yc_10 + 16000 Yc_11 + 18000 Yc_12
#  + 13000 Yc_13 + 7000 Yc_14 + 16000 Yc_2 + 18000 Yc_3 + 11000 Yc_4
#  + 17000 Yc_5 + 20000 Yc_6 + 9000 Yc_7 + 13000 Yc_8 + 11000 Yc_9 >= 140000
#
# _C81: Yc_0 + Yc_1 + Yc_10 + Yc_11 + Yc_12 + Yc_13 + Yc_14 + Yc_2 + Yc_3 + Yc_4
#  + Yc_5 + Yc_6 + Yc_7 + Yc_8 + Yc_9 >= 6
#
# VARIABLES
# 0 <= Xab_0 Integer
# 0 <= Xb0_c_0 Integer
# 0 <= Xb0_c_1 Integer
# 0 <= Xb0_c_10 Integer
# 0 <= Xb0_c_11 Integer
# 0 <= Xb0_c_12 Integer
# 0 <= Xb0_c_13 Integer
# 0 <= Xb0_c_14 Integer
# 0 <= Xb0_c_2 Integer
# 0 <= Xb0_c_3 Integer
# 0 <= Xb0_c_4 Integer
# 0 <= Xb0_c_5 Integer
# 0 <= Xb0_c_6 Integer
# 0 <= Xb0_c_7 Integer
# 0 <= Xb0_c_8 Integer
# 0 <= Xb0_c_9 Integer
# 0 <= Xb0_rev_c_0 Integer
# 0 <= Xb0_rev_c_1 Integer
# 0 <= Xb0_rev_c_10 Integer
# 0 <= Xb0_rev_c_11 Integer
# 0 <= Xb0_rev_c_12 Integer
# 0 <= Xb0_rev_c_13 Integer
# 0 <= Xb0_rev_c_14 Integer
# 0 <= Xb0_rev_c_2 Integer
# 0 <= Xb0_rev_c_3 Integer
# 0 <= Xb0_rev_c_4 Integer
# 0 <= Xb0_rev_c_5 Integer
# 0 <= Xb0_rev_c_6 Integer
# 0 <= Xb0_rev_c_7 Integer
# 0 <= Xb0_rev_c_8 Integer
# 0 <= Xb0_rev_c_9 Integer
# 0 <= Xdb_0 Integer
# 0 <= Yb_0 <= 1 Integer
# 0 <= Yc_0 <= 1 Integer
# 0 <= Yc_1 <= 1 Integer
# 0 <= Yc_10 <= 1 Integer
# 0 <= Yc_11 <= 1 Integer
# 0 <= Yc_12 <= 1 Integer
# 0 <= Yc_13 <= 1 Integer
# 0 <= Yc_14 <= 1 Integer
# 0 <= Yc_2 <= 1 Integer
# 0 <= Yc_3 <= 1 Integer
# 0 <= Yc_4 <= 1 Integer
# 0 <= Yc_5 <= 1 Integer
# 0 <= Yc_6 <= 1 Integer
# 0 <= Yc_7 <= 1 Integer
# 0 <= Yc_8 <= 1 Integer
# 0 <= Yc_9 <= 1 Integer
# s2 Continuous
#
# grid point no:  3 val:  [1.32255922e+09]
# Min:
# MINIMIZE
# 26.64*Xab_0 + 8.0*Xb0_c_0 + 9.0*Xb0_c_1 + 21.0*Xb0_c_10 + 26.0*Xb0_c_11 + 16.0*Xb0_c_12 + 12.0*Xb0_c_13 + 18.0*Xb0_c_14 + 13.0*Xb0_c_2 + 14.0*Xb0_c_3 + 16.0*Xb0_c_4 + 16.0*Xb0_c_5 + 15.0*Xb0_c_6 + 23.0*Xb0_c_7 + 15.0*Xb0_c_8 + 22.0*Xb0_c_9 + 8.0*Xb0_rev_c_0 + 9.0*Xb0_rev_c_1 + 21.0*Xb0_rev_c_10 + 26.0*Xb0_rev_c_11 + 16.0*Xb0_rev_c_12 + 12.0*Xb0_rev_c_13 + 18.0*Xb0_rev_c_14 + 13.0*Xb0_rev_c_2 + 14.0*Xb0_rev_c_3 + 16.0*Xb0_rev_c_4 + 16.0*Xb0_rev_c_5 + 15.0*Xb0_rev_c_6 + 23.0*Xb0_rev_c_7 + 15.0*Xb0_rev_c_8 + 22.0*Xb0_rev_c_9 + 400*Xdb_0 + 5500000*Yb_0 + 726000.0*Yc_0 + 366000.0*Yc_1 + 612000.0*Yc_10 + 552000.0*Yc_11 + 582000.0*Yc_12 + 735000.0*Yc_13 + 513000.0*Yc_14 + 756000.0*Yc_2 + 630000.0*Yc_3 + 393000.0*Yc_4 + 747000.0*Yc_5 + 924000.0*Yc_6 + 423000.0*Yc_7 + 615000.0*Yc_8 + 621000.0*Yc_9 + [1.67336011e-08]*s2 + [0.]
# SUBJECT TO
# _C1: 488.4 Xab_0 + 48 Xb0_c_0 + 54 Xb0_c_1 + 126 Xb0_c_10 + 156 Xb0_c_11
#  + 96 Xb0_c_12 + 72 Xb0_c_13 + 108 Xb0_c_14 + 78 Xb0_c_2 + 84 Xb0_c_3
#  + 96 Xb0_c_4 + 96 Xb0_c_5 + 90 Xb0_c_6 + 138 Xb0_c_7 + 90 Xb0_c_8
#  + 132 Xb0_c_9 + 48 Xb0_rev_c_0 + 54 Xb0_rev_c_1 + 126 Xb0_rev_c_10
#  + 156 Xb0_rev_c_11 + 96 Xb0_rev_c_12 + 72 Xb0_rev_c_13 + 108 Xb0_rev_c_14
#  + 78 Xb0_rev_c_2 + 84 Xb0_rev_c_3 + 96 Xb0_rev_c_4 + 96 Xb0_rev_c_5
#  + 90 Xb0_rev_c_6 + 138 Xb0_rev_c_7 + 90 Xb0_rev_c_8 + 132 Xb0_rev_c_9
#  + 169803000 Yc_0 + 94335000 Yc_1 + 113202000 Yc_10 + 150936000 Yc_11
#  + 169803000 Yc_12 + 122635500 Yc_13 + 66034500 Yc_14 + 150936000 Yc_2
#  + 169803000 Yc_3 + 103768500 Yc_4 + 160369500 Yc_5 + 188670000 Yc_6
#  + 84901500 Yc_7 + 122635500 Yc_8 + 103768500 Yc_9 + s2 = 1322559216
#
# _C2: Xb0_rev_c_0 - 360 Yc_0 >= 0
#
# _C3: Xb0_rev_c_1 - 200 Yc_1 >= 0
#
# _C4: Xb0_rev_c_2 - 320 Yc_2 >= 0
#
# _C5: Xb0_rev_c_3 - 360 Yc_3 >= 0
#
# _C6: Xb0_rev_c_4 - 220 Yc_4 >= 0
#
# _C7: Xb0_rev_c_5 - 340 Yc_5 >= 0
#
# _C8: Xb0_rev_c_6 - 400 Yc_6 >= 0
#
# _C9: Xb0_rev_c_7 - 180 Yc_7 >= 0
#
# _C10: Xb0_rev_c_8 - 260 Yc_8 >= 0
#
# _C11: Xb0_rev_c_9 - 220 Yc_9 >= 0
#
# _C12: Xb0_rev_c_10 - 240 Yc_10 >= 0
#
# _C13: Xb0_rev_c_11 - 320 Yc_11 >= 0
#
# _C14: Xb0_rev_c_12 - 360 Yc_12 >= 0
#
# _C15: Xb0_rev_c_13 - 260 Yc_13 >= 0
#
# _C16: Xb0_rev_c_14 - 140 Yc_14 >= 0
#
# _C17: - 2e-05 Xb0_c_0 + Yb_0 >= 0
#
# _C18: - 2e-05 Xb0_rev_c_0 + Yb_0 >= 0
#
# _C19: - 2e-05 Xb0_c_1 + Yb_0 >= 0
#
# _C20: - 2e-05 Xb0_rev_c_1 + Yb_0 >= 0
#
# _C21: - 2e-05 Xb0_c_2 + Yb_0 >= 0
#
# _C22: - 2e-05 Xb0_rev_c_2 + Yb_0 >= 0
#
# _C23: - 2e-05 Xb0_c_3 + Yb_0 >= 0
#
# _C24: - 2e-05 Xb0_rev_c_3 + Yb_0 >= 0
#
# _C25: - 2e-05 Xb0_c_4 + Yb_0 >= 0
#
# _C26: - 2e-05 Xb0_rev_c_4 + Yb_0 >= 0
#
# _C27: - 2e-05 Xb0_c_5 + Yb_0 >= 0
#
# _C28: - 2e-05 Xb0_rev_c_5 + Yb_0 >= 0
#
# _C29: - 2e-05 Xb0_c_6 + Yb_0 >= 0
#
# _C30: - 2e-05 Xb0_rev_c_6 + Yb_0 >= 0
#
# _C31: - 2e-05 Xb0_c_7 + Yb_0 >= 0
#
# _C32: - 2e-05 Xb0_rev_c_7 + Yb_0 >= 0
#
# _C33: - 2e-05 Xb0_c_8 + Yb_0 >= 0
#
# _C34: - 2e-05 Xb0_rev_c_8 + Yb_0 >= 0
#
# _C35: - 2e-05 Xb0_c_9 + Yb_0 >= 0
#
# _C36: - 2e-05 Xb0_rev_c_9 + Yb_0 >= 0
#
# _C37: - 2e-05 Xb0_c_10 + Yb_0 >= 0
#
# _C38: - 2e-05 Xb0_rev_c_10 + Yb_0 >= 0
#
# _C39: - 2e-05 Xb0_c_11 + Yb_0 >= 0
#
# _C40: - 2e-05 Xb0_rev_c_11 + Yb_0 >= 0
#
# _C41: - 2e-05 Xb0_c_12 + Yb_0 >= 0
#
# _C42: - 2e-05 Xb0_rev_c_12 + Yb_0 >= 0
#
# _C43: - 2e-05 Xb0_c_13 + Yb_0 >= 0
#
# _C44: - 2e-05 Xb0_rev_c_13 + Yb_0 >= 0
#
# _C45: - 2e-05 Xb0_c_14 + Yb_0 >= 0
#
# _C46: - 2e-05 Xb0_rev_c_14 + Yb_0 >= 0
#
# _C47: - Xb0_rev_c_0 - Xb0_rev_c_1 - Xb0_rev_c_10 - Xb0_rev_c_11 - Xb0_rev_c_12
#  - Xb0_rev_c_13 - Xb0_rev_c_14 - Xb0_rev_c_2 - Xb0_rev_c_3 - Xb0_rev_c_4
#  - Xb0_rev_c_5 - Xb0_rev_c_6 - Xb0_rev_c_7 - Xb0_rev_c_8 - Xb0_rev_c_9 + Xdb_0
#  = 0
#
# _C48: Xb0_c_0 - Xb0_rev_c_0 - 240000 Yc_0 <= 0
#
# _C49: Xb0_c_0 - Xb0_rev_c_0 >= 0
#
# _C50: Xb0_c_1 - Xb0_rev_c_1 - 96000 Yc_1 <= 0
#
# _C51: Xb0_c_1 - Xb0_rev_c_1 >= 0
#
# _C52: Xb0_c_2 - Xb0_rev_c_2 - 324000 Yc_2 <= 0
#
# _C53: Xb0_c_2 - Xb0_rev_c_2 >= 0
#
# _C54: Xb0_c_3 - Xb0_rev_c_3 - 144000 Yc_3 <= 0
#
# _C55: Xb0_c_3 - Xb0_rev_c_3 >= 0
#
# _C56: Xb0_c_4 - Xb0_rev_c_4 - 96000 Yc_4 <= 0
#
# _C57: Xb0_c_4 - Xb0_rev_c_4 >= 0
#
# _C58: Xb0_c_5 - Xb0_rev_c_5 - 288000 Yc_5 <= 0
#
# _C59: Xb0_c_5 - Xb0_rev_c_5 >= 0
#
# _C60: Xb0_c_6 - Xb0_rev_c_6 - 384000 Yc_6 <= 0
#
# _C61: Xb0_c_6 - Xb0_rev_c_6 >= 0
#
# _C62: Xb0_c_7 - Xb0_rev_c_7 - 180000 Yc_7 <= 0
#
# _C63: Xb0_c_7 - Xb0_rev_c_7 >= 0
#
# _C64: Xb0_c_8 - Xb0_rev_c_8 - 264000 Yc_8 <= 0
#
# _C65: Xb0_c_8 - Xb0_rev_c_8 >= 0
#
# _C66: Xb0_c_9 - Xb0_rev_c_9 - 324000 Yc_9 <= 0
#
# _C67: Xb0_c_9 - Xb0_rev_c_9 >= 0
#
# _C68: Xb0_c_10 - Xb0_rev_c_10 - 288000 Yc_10 <= 0
#
# _C69: Xb0_c_10 - Xb0_rev_c_10 >= 0
#
# _C70: Xb0_c_11 - Xb0_rev_c_11 - 120000 Yc_11 <= 0
#
# _C71: Xb0_c_11 - Xb0_rev_c_11 >= 0
#
# _C72: Xb0_c_12 - Xb0_rev_c_12 - 96000 Yc_12 <= 0
#
# _C73: Xb0_c_12 - Xb0_rev_c_12 >= 0
#
# _C74: Xb0_c_13 - Xb0_rev_c_13 - 384000 Yc_13 <= 0
#
# _C75: Xb0_c_13 - Xb0_rev_c_13 >= 0
#
# _C76: Xb0_c_14 - Xb0_rev_c_14 - 324000 Yc_14 <= 0
#
# _C77: Xb0_c_14 - Xb0_rev_c_14 >= 0
#
# _C78: Xab_0 - Xb0_c_0 + Xb0_rev_c_0 - Xdb_0 - 13500000 Yb_0 <= 0
#
# _C79: Xab_0 - Xb0_c_0 + Xb0_rev_c_0 - Xdb_0 >= 0
#
# _C80: 18000 Yc_0 + 10000 Yc_1 + 12000 Yc_10 + 16000 Yc_11 + 18000 Yc_12
#  + 13000 Yc_13 + 7000 Yc_14 + 16000 Yc_2 + 18000 Yc_3 + 11000 Yc_4
#  + 17000 Yc_5 + 20000 Yc_6 + 9000 Yc_7 + 13000 Yc_8 + 11000 Yc_9 >= 140000
#
# _C81: Yc_0 + Yc_1 + Yc_10 + Yc_11 + Yc_12 + Yc_13 + Yc_14 + Yc_2 + Yc_3 + Yc_4
#  + Yc_5 + Yc_6 + Yc_7 + Yc_8 + Yc_9 >= 6
#
# VARIABLES
# 0 <= Xab_0 Integer
# 0 <= Xb0_c_0 Integer
# 0 <= Xb0_c_1 Integer
# 0 <= Xb0_c_10 Integer
# 0 <= Xb0_c_11 Integer
# 0 <= Xb0_c_12 Integer
# 0 <= Xb0_c_13 Integer
# 0 <= Xb0_c_14 Integer
# 0 <= Xb0_c_2 Integer
# 0 <= Xb0_c_3 Integer
# 0 <= Xb0_c_4 Integer
# 0 <= Xb0_c_5 Integer
# 0 <= Xb0_c_6 Integer
# 0 <= Xb0_c_7 Integer
# 0 <= Xb0_c_8 Integer
# 0 <= Xb0_c_9 Integer
# 0 <= Xb0_rev_c_0 Integer
# 0 <= Xb0_rev_c_1 Integer
# 0 <= Xb0_rev_c_10 Integer
# 0 <= Xb0_rev_c_11 Integer
# 0 <= Xb0_rev_c_12 Integer
# 0 <= Xb0_rev_c_13 Integer
# 0 <= Xb0_rev_c_14 Integer
# 0 <= Xb0_rev_c_2 Integer
# 0 <= Xb0_rev_c_3 Integer
# 0 <= Xb0_rev_c_4 Integer
# 0 <= Xb0_rev_c_5 Integer
# 0 <= Xb0_rev_c_6 Integer
# 0 <= Xb0_rev_c_7 Integer
# 0 <= Xb0_rev_c_8 Integer
# 0 <= Xb0_rev_c_9 Integer
# 0 <= Xdb_0 Integer
# 0 <= Yb_0 <= 1 Integer
# 0 <= Yc_0 <= 1 Integer
# 0 <= Yc_1 <= 1 Integer
# 0 <= Yc_10 <= 1 Integer
# 0 <= Yc_11 <= 1 Integer
# 0 <= Yc_12 <= 1 Integer
# 0 <= Yc_13 <= 1 Integer
# 0 <= Yc_14 <= 1 Integer
# 0 <= Yc_2 <= 1 Integer
# 0 <= Yc_3 <= 1 Integer
# 0 <= Yc_4 <= 1 Integer
# 0 <= Yc_5 <= 1 Integer
# 0 <= Yc_6 <= 1 Integer
# 0 <= Yc_7 <= 1 Integer
# 0 <= Yc_8 <= 1 Integer
# 0 <= Yc_9 <= 1 Integer
# s2 Continuous
#
# grid point no:  4 val:  [1.32254726e+09]
# Min:
# MINIMIZE
# 26.64*Xab_0 + 8.0*Xb0_c_0 + 9.0*Xb0_c_1 + 21.0*Xb0_c_10 + 26.0*Xb0_c_11 + 16.0*Xb0_c_12 + 12.0*Xb0_c_13 + 18.0*Xb0_c_14 + 13.0*Xb0_c_2 + 14.0*Xb0_c_3 + 16.0*Xb0_c_4 + 16.0*Xb0_c_5 + 15.0*Xb0_c_6 + 23.0*Xb0_c_7 + 15.0*Xb0_c_8 + 22.0*Xb0_c_9 + 8.0*Xb0_rev_c_0 + 9.0*Xb0_rev_c_1 + 21.0*Xb0_rev_c_10 + 26.0*Xb0_rev_c_11 + 16.0*Xb0_rev_c_12 + 12.0*Xb0_rev_c_13 + 18.0*Xb0_rev_c_14 + 13.0*Xb0_rev_c_2 + 14.0*Xb0_rev_c_3 + 16.0*Xb0_rev_c_4 + 16.0*Xb0_rev_c_5 + 15.0*Xb0_rev_c_6 + 23.0*Xb0_rev_c_7 + 15.0*Xb0_rev_c_8 + 22.0*Xb0_rev_c_9 + 400*Xdb_0 + 5500000*Yb_0 + 726000.0*Yc_0 + 366000.0*Yc_1 + 612000.0*Yc_10 + 552000.0*Yc_11 + 582000.0*Yc_12 + 735000.0*Yc_13 + 513000.0*Yc_14 + 756000.0*Yc_2 + 630000.0*Yc_3 + 393000.0*Yc_4 + 747000.0*Yc_5 + 924000.0*Yc_6 + 423000.0*Yc_7 + 615000.0*Yc_8 + 621000.0*Yc_9 + [1.67336011e-08]*s2 + [0.]
# SUBJECT TO
# _C1: 488.4 Xab_0 + 48 Xb0_c_0 + 54 Xb0_c_1 + 126 Xb0_c_10 + 156 Xb0_c_11
#  + 96 Xb0_c_12 + 72 Xb0_c_13 + 108 Xb0_c_14 + 78 Xb0_c_2 + 84 Xb0_c_3
#  + 96 Xb0_c_4 + 96 Xb0_c_5 + 90 Xb0_c_6 + 138 Xb0_c_7 + 90 Xb0_c_8
#  + 132 Xb0_c_9 + 48 Xb0_rev_c_0 + 54 Xb0_rev_c_1 + 126 Xb0_rev_c_10
#  + 156 Xb0_rev_c_11 + 96 Xb0_rev_c_12 + 72 Xb0_rev_c_13 + 108 Xb0_rev_c_14
#  + 78 Xb0_rev_c_2 + 84 Xb0_rev_c_3 + 96 Xb0_rev_c_4 + 96 Xb0_rev_c_5
#  + 90 Xb0_rev_c_6 + 138 Xb0_rev_c_7 + 90 Xb0_rev_c_8 + 132 Xb0_rev_c_9
#  + 169803000 Yc_0 + 94335000 Yc_1 + 113202000 Yc_10 + 150936000 Yc_11
#  + 169803000 Yc_12 + 122635500 Yc_13 + 66034500 Yc_14 + 150936000 Yc_2
#  + 169803000 Yc_3 + 103768500 Yc_4 + 160369500 Yc_5 + 188670000 Yc_6
#  + 84901500 Yc_7 + 122635500 Yc_8 + 103768500 Yc_9 + s2 = 1322547264
#
# _C2: Xb0_rev_c_0 - 360 Yc_0 >= 0
#
# _C3: Xb0_rev_c_1 - 200 Yc_1 >= 0
#
# _C4: Xb0_rev_c_2 - 320 Yc_2 >= 0
#
# _C5: Xb0_rev_c_3 - 360 Yc_3 >= 0
#
# _C6: Xb0_rev_c_4 - 220 Yc_4 >= 0
#
# _C7: Xb0_rev_c_5 - 340 Yc_5 >= 0
#
# _C8: Xb0_rev_c_6 - 400 Yc_6 >= 0
#
# _C9: Xb0_rev_c_7 - 180 Yc_7 >= 0
#
# _C10: Xb0_rev_c_8 - 260 Yc_8 >= 0
#
# _C11: Xb0_rev_c_9 - 220 Yc_9 >= 0
#
# _C12: Xb0_rev_c_10 - 240 Yc_10 >= 0
#
# _C13: Xb0_rev_c_11 - 320 Yc_11 >= 0
#
# _C14: Xb0_rev_c_12 - 360 Yc_12 >= 0
#
# _C15: Xb0_rev_c_13 - 260 Yc_13 >= 0
#
# _C16: Xb0_rev_c_14 - 140 Yc_14 >= 0
#
# _C17: - 2e-05 Xb0_c_0 + Yb_0 >= 0
#
# _C18: - 2e-05 Xb0_rev_c_0 + Yb_0 >= 0
#
# _C19: - 2e-05 Xb0_c_1 + Yb_0 >= 0
#
# _C20: - 2e-05 Xb0_rev_c_1 + Yb_0 >= 0
#
# _C21: - 2e-05 Xb0_c_2 + Yb_0 >= 0
#
# _C22: - 2e-05 Xb0_rev_c_2 + Yb_0 >= 0
#
# _C23: - 2e-05 Xb0_c_3 + Yb_0 >= 0
#
# _C24: - 2e-05 Xb0_rev_c_3 + Yb_0 >= 0
#
# _C25: - 2e-05 Xb0_c_4 + Yb_0 >= 0
#
# _C26: - 2e-05 Xb0_rev_c_4 + Yb_0 >= 0
#
# _C27: - 2e-05 Xb0_c_5 + Yb_0 >= 0
#
# _C28: - 2e-05 Xb0_rev_c_5 + Yb_0 >= 0
#
# _C29: - 2e-05 Xb0_c_6 + Yb_0 >= 0
#
# _C30: - 2e-05 Xb0_rev_c_6 + Yb_0 >= 0
#
# _C31: - 2e-05 Xb0_c_7 + Yb_0 >= 0
#
# _C32: - 2e-05 Xb0_rev_c_7 + Yb_0 >= 0
#
# _C33: - 2e-05 Xb0_c_8 + Yb_0 >= 0
#
# _C34: - 2e-05 Xb0_rev_c_8 + Yb_0 >= 0
#
# _C35: - 2e-05 Xb0_c_9 + Yb_0 >= 0
#
# _C36: - 2e-05 Xb0_rev_c_9 + Yb_0 >= 0
#
# _C37: - 2e-05 Xb0_c_10 + Yb_0 >= 0
#
# _C38: - 2e-05 Xb0_rev_c_10 + Yb_0 >= 0
#
# _C39: - 2e-05 Xb0_c_11 + Yb_0 >= 0
#
# _C40: - 2e-05 Xb0_rev_c_11 + Yb_0 >= 0
#
# _C41: - 2e-05 Xb0_c_12 + Yb_0 >= 0
#
# _C42: - 2e-05 Xb0_rev_c_12 + Yb_0 >= 0
#
# _C43: - 2e-05 Xb0_c_13 + Yb_0 >= 0
#
# _C44: - 2e-05 Xb0_rev_c_13 + Yb_0 >= 0
#
# _C45: - 2e-05 Xb0_c_14 + Yb_0 >= 0
#
# _C46: - 2e-05 Xb0_rev_c_14 + Yb_0 >= 0
#
# _C47: - Xb0_rev_c_0 - Xb0_rev_c_1 - Xb0_rev_c_10 - Xb0_rev_c_11 - Xb0_rev_c_12
#  - Xb0_rev_c_13 - Xb0_rev_c_14 - Xb0_rev_c_2 - Xb0_rev_c_3 - Xb0_rev_c_4
#  - Xb0_rev_c_5 - Xb0_rev_c_6 - Xb0_rev_c_7 - Xb0_rev_c_8 - Xb0_rev_c_9 + Xdb_0
#  = 0
#
# _C48: Xb0_c_0 - Xb0_rev_c_0 - 240000 Yc_0 <= 0
#
# _C49: Xb0_c_0 - Xb0_rev_c_0 >= 0
#
# _C50: Xb0_c_1 - Xb0_rev_c_1 - 96000 Yc_1 <= 0
#
# _C51: Xb0_c_1 - Xb0_rev_c_1 >= 0
#
# _C52: Xb0_c_2 - Xb0_rev_c_2 - 324000 Yc_2 <= 0
#
# _C53: Xb0_c_2 - Xb0_rev_c_2 >= 0
#
# _C54: Xb0_c_3 - Xb0_rev_c_3 - 144000 Yc_3 <= 0
#
# _C55: Xb0_c_3 - Xb0_rev_c_3 >= 0
#
# _C56: Xb0_c_4 - Xb0_rev_c_4 - 96000 Yc_4 <= 0
#
# _C57: Xb0_c_4 - Xb0_rev_c_4 >= 0
#
# _C58: Xb0_c_5 - Xb0_rev_c_5 - 288000 Yc_5 <= 0
#
# _C59: Xb0_c_5 - Xb0_rev_c_5 >= 0
#
# _C60: Xb0_c_6 - Xb0_rev_c_6 - 384000 Yc_6 <= 0
#
# _C61: Xb0_c_6 - Xb0_rev_c_6 >= 0
#
# _C62: Xb0_c_7 - Xb0_rev_c_7 - 180000 Yc_7 <= 0
#
# _C63: Xb0_c_7 - Xb0_rev_c_7 >= 0
#
# _C64: Xb0_c_8 - Xb0_rev_c_8 - 264000 Yc_8 <= 0
#
# _C65: Xb0_c_8 - Xb0_rev_c_8 >= 0
#
# _C66: Xb0_c_9 - Xb0_rev_c_9 - 324000 Yc_9 <= 0
#
# _C67: Xb0_c_9 - Xb0_rev_c_9 >= 0
#
# _C68: Xb0_c_10 - Xb0_rev_c_10 - 288000 Yc_10 <= 0
#
# _C69: Xb0_c_10 - Xb0_rev_c_10 >= 0
#
# _C70: Xb0_c_11 - Xb0_rev_c_11 - 120000 Yc_11 <= 0
#
# _C71: Xb0_c_11 - Xb0_rev_c_11 >= 0
#
# _C72: Xb0_c_12 - Xb0_rev_c_12 - 96000 Yc_12 <= 0
#
# _C73: Xb0_c_12 - Xb0_rev_c_12 >= 0
#
# _C74: Xb0_c_13 - Xb0_rev_c_13 - 384000 Yc_13 <= 0
#
# _C75: Xb0_c_13 - Xb0_rev_c_13 >= 0
#
# _C76: Xb0_c_14 - Xb0_rev_c_14 - 324000 Yc_14 <= 0
#
# _C77: Xb0_c_14 - Xb0_rev_c_14 >= 0
#
# _C78: Xab_0 - Xb0_c_0 + Xb0_rev_c_0 - Xdb_0 - 13500000 Yb_0 <= 0
#
# _C79: Xab_0 - Xb0_c_0 + Xb0_rev_c_0 - Xdb_0 >= 0
#
# _C80: 18000 Yc_0 + 10000 Yc_1 + 12000 Yc_10 + 16000 Yc_11 + 18000 Yc_12
#  + 13000 Yc_13 + 7000 Yc_14 + 16000 Yc_2 + 18000 Yc_3 + 11000 Yc_4
#  + 17000 Yc_5 + 20000 Yc_6 + 9000 Yc_7 + 13000 Yc_8 + 11000 Yc_9 >= 140000
#
# _C81: Yc_0 + Yc_1 + Yc_10 + Yc_11 + Yc_12 + Yc_13 + Yc_14 + Yc_2 + Yc_3 + Yc_4
#  + Yc_5 + Yc_6 + Yc_7 + Yc_8 + Yc_9 >= 6
#
# VARIABLES
# 0 <= Xab_0 Integer
# 0 <= Xb0_c_0 Integer
# 0 <= Xb0_c_1 Integer
# 0 <= Xb0_c_10 Integer
# 0 <= Xb0_c_11 Integer
# 0 <= Xb0_c_12 Integer
# 0 <= Xb0_c_13 Integer
# 0 <= Xb0_c_14 Integer
# 0 <= Xb0_c_2 Integer
# 0 <= Xb0_c_3 Integer
# 0 <= Xb0_c_4 Integer
# 0 <= Xb0_c_5 Integer
# 0 <= Xb0_c_6 Integer
# 0 <= Xb0_c_7 Integer
# 0 <= Xb0_c_8 Integer
# 0 <= Xb0_c_9 Integer
# 0 <= Xb0_rev_c_0 Integer
# 0 <= Xb0_rev_c_1 Integer
# 0 <= Xb0_rev_c_10 Integer
# 0 <= Xb0_rev_c_11 Integer
# 0 <= Xb0_rev_c_12 Integer
# 0 <= Xb0_rev_c_13 Integer
# 0 <= Xb0_rev_c_14 Integer
# 0 <= Xb0_rev_c_2 Integer
# 0 <= Xb0_rev_c_3 Integer
# 0 <= Xb0_rev_c_4 Integer
# 0 <= Xb0_rev_c_5 Integer
# 0 <= Xb0_rev_c_6 Integer
# 0 <= Xb0_rev_c_7 Integer
# 0 <= Xb0_rev_c_8 Integer
# 0 <= Xb0_rev_c_9 Integer
# 0 <= Xdb_0 Integer
# 0 <= Yb_0 <= 1 Integer
# 0 <= Yc_0 <= 1 Integer
# 0 <= Yc_1 <= 1 Integer
# 0 <= Yc_10 <= 1 Integer
# 0 <= Yc_11 <= 1 Integer
# 0 <= Yc_12 <= 1 Integer
# 0 <= Yc_13 <= 1 Integer
# 0 <= Yc_14 <= 1 Integer
# 0 <= Yc_2 <= 1 Integer
# 0 <= Yc_3 <= 1 Integer
# 0 <= Yc_4 <= 1 Integer
# 0 <= Yc_5 <= 1 Integer
# 0 <= Yc_6 <= 1 Integer
# 0 <= Yc_7 <= 1 Integer
# 0 <= Yc_8 <= 1 Integer
# 0 <= Yc_9 <= 1 Integer
# s2 Continuous
#
# grid point no:  5 val:  [1.32253531e+09]
# Min:
# MINIMIZE
# 26.64*Xab_0 + 8.0*Xb0_c_0 + 9.0*Xb0_c_1 + 21.0*Xb0_c_10 + 26.0*Xb0_c_11 + 16.0*Xb0_c_12 + 12.0*Xb0_c_13 + 18.0*Xb0_c_14 + 13.0*Xb0_c_2 + 14.0*Xb0_c_3 + 16.0*Xb0_c_4 + 16.0*Xb0_c_5 + 15.0*Xb0_c_6 + 23.0*Xb0_c_7 + 15.0*Xb0_c_8 + 22.0*Xb0_c_9 + 8.0*Xb0_rev_c_0 + 9.0*Xb0_rev_c_1 + 21.0*Xb0_rev_c_10 + 26.0*Xb0_rev_c_11 + 16.0*Xb0_rev_c_12 + 12.0*Xb0_rev_c_13 + 18.0*Xb0_rev_c_14 + 13.0*Xb0_rev_c_2 + 14.0*Xb0_rev_c_3 + 16.0*Xb0_rev_c_4 + 16.0*Xb0_rev_c_5 + 15.0*Xb0_rev_c_6 + 23.0*Xb0_rev_c_7 + 15.0*Xb0_rev_c_8 + 22.0*Xb0_rev_c_9 + 400*Xdb_0 + 5500000*Yb_0 + 726000.0*Yc_0 + 366000.0*Yc_1 + 612000.0*Yc_10 + 552000.0*Yc_11 + 582000.0*Yc_12 + 735000.0*Yc_13 + 513000.0*Yc_14 + 756000.0*Yc_2 + 630000.0*Yc_3 + 393000.0*Yc_4 + 747000.0*Yc_5 + 924000.0*Yc_6 + 423000.0*Yc_7 + 615000.0*Yc_8 + 621000.0*Yc_9 + [1.67336011e-08]*s2 + [0.]
# SUBJECT TO
# _C1: 488.4 Xab_0 + 48 Xb0_c_0 + 54 Xb0_c_1 + 126 Xb0_c_10 + 156 Xb0_c_11
#  + 96 Xb0_c_12 + 72 Xb0_c_13 + 108 Xb0_c_14 + 78 Xb0_c_2 + 84 Xb0_c_3
#  + 96 Xb0_c_4 + 96 Xb0_c_5 + 90 Xb0_c_6 + 138 Xb0_c_7 + 90 Xb0_c_8
#  + 132 Xb0_c_9 + 48 Xb0_rev_c_0 + 54 Xb0_rev_c_1 + 126 Xb0_rev_c_10
#  + 156 Xb0_rev_c_11 + 96 Xb0_rev_c_12 + 72 Xb0_rev_c_13 + 108 Xb0_rev_c_14
#  + 78 Xb0_rev_c_2 + 84 Xb0_rev_c_3 + 96 Xb0_rev_c_4 + 96 Xb0_rev_c_5
#  + 90 Xb0_rev_c_6 + 138 Xb0_rev_c_7 + 90 Xb0_rev_c_8 + 132 Xb0_rev_c_9
#  + 169803000 Yc_0 + 94335000 Yc_1 + 113202000 Yc_10 + 150936000 Yc_11
#  + 169803000 Yc_12 + 122635500 Yc_13 + 66034500 Yc_14 + 150936000 Yc_2
#  + 169803000 Yc_3 + 103768500 Yc_4 + 160369500 Yc_5 + 188670000 Yc_6
#  + 84901500 Yc_7 + 122635500 Yc_8 + 103768500 Yc_9 + s2 = 1322535312
#
# _C2: Xb0_rev_c_0 - 360 Yc_0 >= 0
#
# _C3: Xb0_rev_c_1 - 200 Yc_1 >= 0
#
# _C4: Xb0_rev_c_2 - 320 Yc_2 >= 0
#
# _C5: Xb0_rev_c_3 - 360 Yc_3 >= 0
#
# _C6: Xb0_rev_c_4 - 220 Yc_4 >= 0
#
# _C7: Xb0_rev_c_5 - 340 Yc_5 >= 0
#
# _C8: Xb0_rev_c_6 - 400 Yc_6 >= 0
#
# _C9: Xb0_rev_c_7 - 180 Yc_7 >= 0
#
# _C10: Xb0_rev_c_8 - 260 Yc_8 >= 0
#
# _C11: Xb0_rev_c_9 - 220 Yc_9 >= 0
#
# _C12: Xb0_rev_c_10 - 240 Yc_10 >= 0
#
# _C13: Xb0_rev_c_11 - 320 Yc_11 >= 0
#
# _C14: Xb0_rev_c_12 - 360 Yc_12 >= 0
#
# _C15: Xb0_rev_c_13 - 260 Yc_13 >= 0
#
# _C16: Xb0_rev_c_14 - 140 Yc_14 >= 0
#
# _C17: - 2e-05 Xb0_c_0 + Yb_0 >= 0
#
# _C18: - 2e-05 Xb0_rev_c_0 + Yb_0 >= 0
#
# _C19: - 2e-05 Xb0_c_1 + Yb_0 >= 0
#
# _C20: - 2e-05 Xb0_rev_c_1 + Yb_0 >= 0
#
# _C21: - 2e-05 Xb0_c_2 + Yb_0 >= 0
#
# _C22: - 2e-05 Xb0_rev_c_2 + Yb_0 >= 0
#
# _C23: - 2e-05 Xb0_c_3 + Yb_0 >= 0
#
# _C24: - 2e-05 Xb0_rev_c_3 + Yb_0 >= 0
#
# _C25: - 2e-05 Xb0_c_4 + Yb_0 >= 0
#
# _C26: - 2e-05 Xb0_rev_c_4 + Yb_0 >= 0
#
# _C27: - 2e-05 Xb0_c_5 + Yb_0 >= 0
#
# _C28: - 2e-05 Xb0_rev_c_5 + Yb_0 >= 0
#
# _C29: - 2e-05 Xb0_c_6 + Yb_0 >= 0
#
# _C30: - 2e-05 Xb0_rev_c_6 + Yb_0 >= 0
#
# _C31: - 2e-05 Xb0_c_7 + Yb_0 >= 0
#
# _C32: - 2e-05 Xb0_rev_c_7 + Yb_0 >= 0
#
# _C33: - 2e-05 Xb0_c_8 + Yb_0 >= 0
#
# _C34: - 2e-05 Xb0_rev_c_8 + Yb_0 >= 0
#
# _C35: - 2e-05 Xb0_c_9 + Yb_0 >= 0
#
# _C36: - 2e-05 Xb0_rev_c_9 + Yb_0 >= 0
#
# _C37: - 2e-05 Xb0_c_10 + Yb_0 >= 0
#
# _C38: - 2e-05 Xb0_rev_c_10 + Yb_0 >= 0
#
# _C39: - 2e-05 Xb0_c_11 + Yb_0 >= 0
#
# _C40: - 2e-05 Xb0_rev_c_11 + Yb_0 >= 0
#
# _C41: - 2e-05 Xb0_c_12 + Yb_0 >= 0
#
# _C42: - 2e-05 Xb0_rev_c_12 + Yb_0 >= 0
#
# _C43: - 2e-05 Xb0_c_13 + Yb_0 >= 0
#
# _C44: - 2e-05 Xb0_rev_c_13 + Yb_0 >= 0
#
# _C45: - 2e-05 Xb0_c_14 + Yb_0 >= 0
#
# _C46: - 2e-05 Xb0_rev_c_14 + Yb_0 >= 0
#
# _C47: - Xb0_rev_c_0 - Xb0_rev_c_1 - Xb0_rev_c_10 - Xb0_rev_c_11 - Xb0_rev_c_12
#  - Xb0_rev_c_13 - Xb0_rev_c_14 - Xb0_rev_c_2 - Xb0_rev_c_3 - Xb0_rev_c_4
#  - Xb0_rev_c_5 - Xb0_rev_c_6 - Xb0_rev_c_7 - Xb0_rev_c_8 - Xb0_rev_c_9 + Xdb_0
#  = 0
#
# _C48: Xb0_c_0 - Xb0_rev_c_0 - 240000 Yc_0 <= 0
#
# _C49: Xb0_c_0 - Xb0_rev_c_0 >= 0
#
# _C50: Xb0_c_1 - Xb0_rev_c_1 - 96000 Yc_1 <= 0
#
# _C51: Xb0_c_1 - Xb0_rev_c_1 >= 0
#
# _C52: Xb0_c_2 - Xb0_rev_c_2 - 324000 Yc_2 <= 0
#
# _C53: Xb0_c_2 - Xb0_rev_c_2 >= 0
#
# _C54: Xb0_c_3 - Xb0_rev_c_3 - 144000 Yc_3 <= 0
#
# _C55: Xb0_c_3 - Xb0_rev_c_3 >= 0
#
# _C56: Xb0_c_4 - Xb0_rev_c_4 - 96000 Yc_4 <= 0
#
# _C57: Xb0_c_4 - Xb0_rev_c_4 >= 0
#
# _C58: Xb0_c_5 - Xb0_rev_c_5 - 288000 Yc_5 <= 0
#
# _C59: Xb0_c_5 - Xb0_rev_c_5 >= 0
#
# _C60: Xb0_c_6 - Xb0_rev_c_6 - 384000 Yc_6 <= 0
#
# _C61: Xb0_c_6 - Xb0_rev_c_6 >= 0
#
# _C62: Xb0_c_7 - Xb0_rev_c_7 - 180000 Yc_7 <= 0
#
# _C63: Xb0_c_7 - Xb0_rev_c_7 >= 0
#
# _C64: Xb0_c_8 - Xb0_rev_c_8 - 264000 Yc_8 <= 0
#
# _C65: Xb0_c_8 - Xb0_rev_c_8 >= 0
#
# _C66: Xb0_c_9 - Xb0_rev_c_9 - 324000 Yc_9 <= 0
#
# _C67: Xb0_c_9 - Xb0_rev_c_9 >= 0
#
# _C68: Xb0_c_10 - Xb0_rev_c_10 - 288000 Yc_10 <= 0
#
# _C69: Xb0_c_10 - Xb0_rev_c_10 >= 0
#
# _C70: Xb0_c_11 - Xb0_rev_c_11 - 120000 Yc_11 <= 0
#
# _C71: Xb0_c_11 - Xb0_rev_c_11 >= 0
#
# _C72: Xb0_c_12 - Xb0_rev_c_12 - 96000 Yc_12 <= 0
#
# _C73: Xb0_c_12 - Xb0_rev_c_12 >= 0
#
# _C74: Xb0_c_13 - Xb0_rev_c_13 - 384000 Yc_13 <= 0
#
# _C75: Xb0_c_13 - Xb0_rev_c_13 >= 0
#
# _C76: Xb0_c_14 - Xb0_rev_c_14 - 324000 Yc_14 <= 0
#
# _C77: Xb0_c_14 - Xb0_rev_c_14 >= 0
#
# _C78: Xab_0 - Xb0_c_0 + Xb0_rev_c_0 - Xdb_0 - 13500000 Yb_0 <= 0
#
# _C79: Xab_0 - Xb0_c_0 + Xb0_rev_c_0 - Xdb_0 >= 0
#
# _C80: 18000 Yc_0 + 10000 Yc_1 + 12000 Yc_10 + 16000 Yc_11 + 18000 Yc_12
#  + 13000 Yc_13 + 7000 Yc_14 + 16000 Yc_2 + 18000 Yc_3 + 11000 Yc_4
#  + 17000 Yc_5 + 20000 Yc_6 + 9000 Yc_7 + 13000 Yc_8 + 11000 Yc_9 >= 140000
#
# _C81: Yc_0 + Yc_1 + Yc_10 + Yc_11 + Yc_12 + Yc_13 + Yc_14 + Yc_2 + Yc_3 + Yc_4
#  + Yc_5 + Yc_6 + Yc_7 + Yc_8 + Yc_9 >= 6
#
# VARIABLES
# 0 <= Xab_0 Integer
# 0 <= Xb0_c_0 Integer
# 0 <= Xb0_c_1 Integer
# 0 <= Xb0_c_10 Integer
# 0 <= Xb0_c_11 Integer
# 0 <= Xb0_c_12 Integer
# 0 <= Xb0_c_13 Integer
# 0 <= Xb0_c_14 Integer
# 0 <= Xb0_c_2 Integer
# 0 <= Xb0_c_3 Integer
# 0 <= Xb0_c_4 Integer
# 0 <= Xb0_c_5 Integer
# 0 <= Xb0_c_6 Integer
# 0 <= Xb0_c_7 Integer
# 0 <= Xb0_c_8 Integer
# 0 <= Xb0_c_9 Integer
# 0 <= Xb0_rev_c_0 Integer
# 0 <= Xb0_rev_c_1 Integer
# 0 <= Xb0_rev_c_10 Integer
# 0 <= Xb0_rev_c_11 Integer
# 0 <= Xb0_rev_c_12 Integer
# 0 <= Xb0_rev_c_13 Integer
# 0 <= Xb0_rev_c_14 Integer
# 0 <= Xb0_rev_c_2 Integer
# 0 <= Xb0_rev_c_3 Integer
# 0 <= Xb0_rev_c_4 Integer
# 0 <= Xb0_rev_c_5 Integer
# 0 <= Xb0_rev_c_6 Integer
# 0 <= Xb0_rev_c_7 Integer
# 0 <= Xb0_rev_c_8 Integer
# 0 <= Xb0_rev_c_9 Integer
# 0 <= Xdb_0 Integer
# 0 <= Yb_0 <= 1 Integer
# 0 <= Yc_0 <= 1 Integer
# 0 <= Yc_1 <= 1 Integer
# 0 <= Yc_10 <= 1 Integer
# 0 <= Yc_11 <= 1 Integer
# 0 <= Yc_12 <= 1 Integer
# 0 <= Yc_13 <= 1 Integer
# 0 <= Yc_14 <= 1 Integer
# 0 <= Yc_2 <= 1 Integer
# 0 <= Yc_3 <= 1 Integer
# 0 <= Yc_4 <= 1 Integer
# 0 <= Yc_5 <= 1 Integer
# 0 <= Yc_6 <= 1 Integer
# 0 <= Yc_7 <= 1 Integer
# 0 <= Yc_8 <= 1 Integer
# 0 <= Yc_9 <= 1 Integer
# s2 Continuous
#
# grid point no:  6 val:  [1.32252336e+09]
# Min:
# MINIMIZE
# 26.64*Xab_0 + 8.0*Xb0_c_0 + 9.0*Xb0_c_1 + 21.0*Xb0_c_10 + 26.0*Xb0_c_11 + 16.0*Xb0_c_12 + 12.0*Xb0_c_13 + 18.0*Xb0_c_14 + 13.0*Xb0_c_2 + 14.0*Xb0_c_3 + 16.0*Xb0_c_4 + 16.0*Xb0_c_5 + 15.0*Xb0_c_6 + 23.0*Xb0_c_7 + 15.0*Xb0_c_8 + 22.0*Xb0_c_9 + 8.0*Xb0_rev_c_0 + 9.0*Xb0_rev_c_1 + 21.0*Xb0_rev_c_10 + 26.0*Xb0_rev_c_11 + 16.0*Xb0_rev_c_12 + 12.0*Xb0_rev_c_13 + 18.0*Xb0_rev_c_14 + 13.0*Xb0_rev_c_2 + 14.0*Xb0_rev_c_3 + 16.0*Xb0_rev_c_4 + 16.0*Xb0_rev_c_5 + 15.0*Xb0_rev_c_6 + 23.0*Xb0_rev_c_7 + 15.0*Xb0_rev_c_8 + 22.0*Xb0_rev_c_9 + 400*Xdb_0 + 5500000*Yb_0 + 726000.0*Yc_0 + 366000.0*Yc_1 + 612000.0*Yc_10 + 552000.0*Yc_11 + 582000.0*Yc_12 + 735000.0*Yc_13 + 513000.0*Yc_14 + 756000.0*Yc_2 + 630000.0*Yc_3 + 393000.0*Yc_4 + 747000.0*Yc_5 + 924000.0*Yc_6 + 423000.0*Yc_7 + 615000.0*Yc_8 + 621000.0*Yc_9 + [1.67336011e-08]*s2 + [0.]
# SUBJECT TO
# _C1: 488.4 Xab_0 + 48 Xb0_c_0 + 54 Xb0_c_1 + 126 Xb0_c_10 + 156 Xb0_c_11
#  + 96 Xb0_c_12 + 72 Xb0_c_13 + 108 Xb0_c_14 + 78 Xb0_c_2 + 84 Xb0_c_3
#  + 96 Xb0_c_4 + 96 Xb0_c_5 + 90 Xb0_c_6 + 138 Xb0_c_7 + 90 Xb0_c_8
#  + 132 Xb0_c_9 + 48 Xb0_rev_c_0 + 54 Xb0_rev_c_1 + 126 Xb0_rev_c_10
#  + 156 Xb0_rev_c_11 + 96 Xb0_rev_c_12 + 72 Xb0_rev_c_13 + 108 Xb0_rev_c_14
#  + 78 Xb0_rev_c_2 + 84 Xb0_rev_c_3 + 96 Xb0_rev_c_4 + 96 Xb0_rev_c_5
#  + 90 Xb0_rev_c_6 + 138 Xb0_rev_c_7 + 90 Xb0_rev_c_8 + 132 Xb0_rev_c_9
#  + 169803000 Yc_0 + 94335000 Yc_1 + 113202000 Yc_10 + 150936000 Yc_11
#  + 169803000 Yc_12 + 122635500 Yc_13 + 66034500 Yc_14 + 150936000 Yc_2
#  + 169803000 Yc_3 + 103768500 Yc_4 + 160369500 Yc_5 + 188670000 Yc_6
#  + 84901500 Yc_7 + 122635500 Yc_8 + 103768500 Yc_9 + s2 = 1322523360
#
# _C2: Xb0_rev_c_0 - 360 Yc_0 >= 0
#
# _C3: Xb0_rev_c_1 - 200 Yc_1 >= 0
#
# _C4: Xb0_rev_c_2 - 320 Yc_2 >= 0
#
# _C5: Xb0_rev_c_3 - 360 Yc_3 >= 0
#
# _C6: Xb0_rev_c_4 - 220 Yc_4 >= 0
#
# _C7: Xb0_rev_c_5 - 340 Yc_5 >= 0
#
# _C8: Xb0_rev_c_6 - 400 Yc_6 >= 0
#
# _C9: Xb0_rev_c_7 - 180 Yc_7 >= 0
#
# _C10: Xb0_rev_c_8 - 260 Yc_8 >= 0
#
# _C11: Xb0_rev_c_9 - 220 Yc_9 >= 0
#
# _C12: Xb0_rev_c_10 - 240 Yc_10 >= 0
#
# _C13: Xb0_rev_c_11 - 320 Yc_11 >= 0
#
# _C14: Xb0_rev_c_12 - 360 Yc_12 >= 0
#
# _C15: Xb0_rev_c_13 - 260 Yc_13 >= 0
#
# _C16: Xb0_rev_c_14 - 140 Yc_14 >= 0
#
# _C17: - 2e-05 Xb0_c_0 + Yb_0 >= 0
#
# _C18: - 2e-05 Xb0_rev_c_0 + Yb_0 >= 0
#
# _C19: - 2e-05 Xb0_c_1 + Yb_0 >= 0
#
# _C20: - 2e-05 Xb0_rev_c_1 + Yb_0 >= 0
#
# _C21: - 2e-05 Xb0_c_2 + Yb_0 >= 0
#
# _C22: - 2e-05 Xb0_rev_c_2 + Yb_0 >= 0
#
# _C23: - 2e-05 Xb0_c_3 + Yb_0 >= 0
#
# _C24: - 2e-05 Xb0_rev_c_3 + Yb_0 >= 0
#
# _C25: - 2e-05 Xb0_c_4 + Yb_0 >= 0
#
# _C26: - 2e-05 Xb0_rev_c_4 + Yb_0 >= 0
#
# _C27: - 2e-05 Xb0_c_5 + Yb_0 >= 0
#
# _C28: - 2e-05 Xb0_rev_c_5 + Yb_0 >= 0
#
# _C29: - 2e-05 Xb0_c_6 + Yb_0 >= 0
#
# _C30: - 2e-05 Xb0_rev_c_6 + Yb_0 >= 0
#
# _C31: - 2e-05 Xb0_c_7 + Yb_0 >= 0
#
# _C32: - 2e-05 Xb0_rev_c_7 + Yb_0 >= 0
#
# _C33: - 2e-05 Xb0_c_8 + Yb_0 >= 0
#
# _C34: - 2e-05 Xb0_rev_c_8 + Yb_0 >= 0
#
# _C35: - 2e-05 Xb0_c_9 + Yb_0 >= 0
#
# _C36: - 2e-05 Xb0_rev_c_9 + Yb_0 >= 0
#
# _C37: - 2e-05 Xb0_c_10 + Yb_0 >= 0
#
# _C38: - 2e-05 Xb0_rev_c_10 + Yb_0 >= 0
#
# _C39: - 2e-05 Xb0_c_11 + Yb_0 >= 0
#
# _C40: - 2e-05 Xb0_rev_c_11 + Yb_0 >= 0
#
# _C41: - 2e-05 Xb0_c_12 + Yb_0 >= 0
#
# _C42: - 2e-05 Xb0_rev_c_12 + Yb_0 >= 0
#
# _C43: - 2e-05 Xb0_c_13 + Yb_0 >= 0
#
# _C44: - 2e-05 Xb0_rev_c_13 + Yb_0 >= 0
#
# _C45: - 2e-05 Xb0_c_14 + Yb_0 >= 0
#
# _C46: - 2e-05 Xb0_rev_c_14 + Yb_0 >= 0
#
# _C47: - Xb0_rev_c_0 - Xb0_rev_c_1 - Xb0_rev_c_10 - Xb0_rev_c_11 - Xb0_rev_c_12
#  - Xb0_rev_c_13 - Xb0_rev_c_14 - Xb0_rev_c_2 - Xb0_rev_c_3 - Xb0_rev_c_4
#  - Xb0_rev_c_5 - Xb0_rev_c_6 - Xb0_rev_c_7 - Xb0_rev_c_8 - Xb0_rev_c_9 + Xdb_0
#  = 0
#
# _C48: Xb0_c_0 - Xb0_rev_c_0 - 240000 Yc_0 <= 0
#
# _C49: Xb0_c_0 - Xb0_rev_c_0 >= 0
#
# _C50: Xb0_c_1 - Xb0_rev_c_1 - 96000 Yc_1 <= 0
#
# _C51: Xb0_c_1 - Xb0_rev_c_1 >= 0
#
# _C52: Xb0_c_2 - Xb0_rev_c_2 - 324000 Yc_2 <= 0
#
# _C53: Xb0_c_2 - Xb0_rev_c_2 >= 0
#
# _C54: Xb0_c_3 - Xb0_rev_c_3 - 144000 Yc_3 <= 0
#
# _C55: Xb0_c_3 - Xb0_rev_c_3 >= 0
#
# _C56: Xb0_c_4 - Xb0_rev_c_4 - 96000 Yc_4 <= 0
#
# _C57: Xb0_c_4 - Xb0_rev_c_4 >= 0
#
# _C58: Xb0_c_5 - Xb0_rev_c_5 - 288000 Yc_5 <= 0
#
# _C59: Xb0_c_5 - Xb0_rev_c_5 >= 0
#
# _C60: Xb0_c_6 - Xb0_rev_c_6 - 384000 Yc_6 <= 0
#
# _C61: Xb0_c_6 - Xb0_rev_c_6 >= 0
#
# _C62: Xb0_c_7 - Xb0_rev_c_7 - 180000 Yc_7 <= 0
#
# _C63: Xb0_c_7 - Xb0_rev_c_7 >= 0
#
# _C64: Xb0_c_8 - Xb0_rev_c_8 - 264000 Yc_8 <= 0
#
# _C65: Xb0_c_8 - Xb0_rev_c_8 >= 0
#
# _C66: Xb0_c_9 - Xb0_rev_c_9 - 324000 Yc_9 <= 0
#
# _C67: Xb0_c_9 - Xb0_rev_c_9 >= 0
#
# _C68: Xb0_c_10 - Xb0_rev_c_10 - 288000 Yc_10 <= 0
#
# _C69: Xb0_c_10 - Xb0_rev_c_10 >= 0
#
# _C70: Xb0_c_11 - Xb0_rev_c_11 - 120000 Yc_11 <= 0
#
# _C71: Xb0_c_11 - Xb0_rev_c_11 >= 0
#
# _C72: Xb0_c_12 - Xb0_rev_c_12 - 96000 Yc_12 <= 0
#
# _C73: Xb0_c_12 - Xb0_rev_c_12 >= 0
#
# _C74: Xb0_c_13 - Xb0_rev_c_13 - 384000 Yc_13 <= 0
#
# _C75: Xb0_c_13 - Xb0_rev_c_13 >= 0
#
# _C76: Xb0_c_14 - Xb0_rev_c_14 - 324000 Yc_14 <= 0
#
# _C77: Xb0_c_14 - Xb0_rev_c_14 >= 0
#
# _C78: Xab_0 - Xb0_c_0 + Xb0_rev_c_0 - Xdb_0 - 13500000 Yb_0 <= 0
#
# _C79: Xab_0 - Xb0_c_0 + Xb0_rev_c_0 - Xdb_0 >= 0
#
# _C80: 18000 Yc_0 + 10000 Yc_1 + 12000 Yc_10 + 16000 Yc_11 + 18000 Yc_12
#  + 13000 Yc_13 + 7000 Yc_14 + 16000 Yc_2 + 18000 Yc_3 + 11000 Yc_4
#  + 17000 Yc_5 + 20000 Yc_6 + 9000 Yc_7 + 13000 Yc_8 + 11000 Yc_9 >= 140000
#
# _C81: Yc_0 + Yc_1 + Yc_10 + Yc_11 + Yc_12 + Yc_13 + Yc_14 + Yc_2 + Yc_3 + Yc_4
#  + Yc_5 + Yc_6 + Yc_7 + Yc_8 + Yc_9 >= 6
#
# VARIABLES
# 0 <= Xab_0 Integer
# 0 <= Xb0_c_0 Integer
# 0 <= Xb0_c_1 Integer
# 0 <= Xb0_c_10 Integer
# 0 <= Xb0_c_11 Integer
# 0 <= Xb0_c_12 Integer
# 0 <= Xb0_c_13 Integer
# 0 <= Xb0_c_14 Integer
# 0 <= Xb0_c_2 Integer
# 0 <= Xb0_c_3 Integer
# 0 <= Xb0_c_4 Integer
# 0 <= Xb0_c_5 Integer
# 0 <= Xb0_c_6 Integer
# 0 <= Xb0_c_7 Integer
# 0 <= Xb0_c_8 Integer
# 0 <= Xb0_c_9 Integer
# 0 <= Xb0_rev_c_0 Integer
# 0 <= Xb0_rev_c_1 Integer
# 0 <= Xb0_rev_c_10 Integer
# 0 <= Xb0_rev_c_11 Integer
# 0 <= Xb0_rev_c_12 Integer
# 0 <= Xb0_rev_c_13 Integer
# 0 <= Xb0_rev_c_14 Integer
# 0 <= Xb0_rev_c_2 Integer
# 0 <= Xb0_rev_c_3 Integer
# 0 <= Xb0_rev_c_4 Integer
# 0 <= Xb0_rev_c_5 Integer
# 0 <= Xb0_rev_c_6 Integer
# 0 <= Xb0_rev_c_7 Integer
# 0 <= Xb0_rev_c_8 Integer
# 0 <= Xb0_rev_c_9 Integer
# 0 <= Xdb_0 Integer
# 0 <= Yb_0 <= 1 Integer
# 0 <= Yc_0 <= 1 Integer
# 0 <= Yc_1 <= 1 Integer
# 0 <= Yc_10 <= 1 Integer
# 0 <= Yc_11 <= 1 Integer
# 0 <= Yc_12 <= 1 Integer
# 0 <= Yc_13 <= 1 Integer
# 0 <= Yc_14 <= 1 Integer
# 0 <= Yc_2 <= 1 Integer
# 0 <= Yc_3 <= 1 Integer
# 0 <= Yc_4 <= 1 Integer
# 0 <= Yc_5 <= 1 Integer
# 0 <= Yc_6 <= 1 Integer
# 0 <= Yc_7 <= 1 Integer
# 0 <= Yc_8 <= 1 Integer
# 0 <= Yc_9 <= 1 Integer
# s2 Continuous

# %%
key_intervals
# Out:
# {0: {Xab_0: 2800.0,
#   Xb0_c_0: 360.0,
#   Xb0_c_1: 200.0,
#   Xb0_c_10: 240.0,
#   Xb0_c_11: 320.0,
#   Xb0_c_12: 360.0,
#   Xb0_c_13: 0.0,
#   Xb0_c_14: 0.0,
#   Xb0_c_2: 0.0,
#   Xb0_c_3: 360.0,
#   Xb0_c_4: 220.0,
#   Xb0_c_5: 340.0,
#   Xb0_c_6: 400.0,
#   Xb0_c_7: 0.0,
#   Xb0_c_8: 0.0,
#   Xb0_c_9: 0.0,
#   Xb0_rev_c_0: 360.0,
#   Xb0_rev_c_1: 200.0,
#   Xb0_rev_c_10: 240.0,
#   Xb0_rev_c_11: 320.0,
#   Xb0_rev_c_12: 360.0,
#   Xb0_rev_c_13: 0.0,
#   Xb0_rev_c_14: 0.0,
#   Xb0_rev_c_2: 0.0,
#   Xb0_rev_c_3: 360.0,
#   Xb0_rev_c_4: 220.0,
#   Xb0_rev_c_5: 340.0,
#   Xb0_rev_c_6: 400.0,
#   Xb0_rev_c_7: 0.0,
#   Xb0_rev_c_8: 0.0,
#   Xb0_rev_c_9: 0.0,
#   Xdb_0: 2800.0,
#   Yb_0: 1.0,
#   Yc_0: 1.0,
#   Yc_1: 1.0,
#   Yc_10: 1.0,
#   Yc_11: 1.0,
#   Yc_12: 1.0,
#   Yc_13: 0.0,
#   Yc_14: 0.0,
#   Yc_2: 0.0,
#   Yc_3: 1.0,
#   Yc_4: 1.0,
#   Yc_5: 1.0,
#   Yc_6: 1.0,
#   Yc_7: 0.0,
#   Yc_8: 0.0,
#   Yc_9: 0.0,
#   s2: 0.0},
#  1: {Xab_0: 2800.0,
#   Xb0_c_0: 360.0,
#   Xb0_c_1: 200.0,
#   Xb0_c_10: 0.0,
#   Xb0_c_11: 320.0,
#   Xb0_c_12: 360.0,
#   Xb0_c_13: 0.0,
#   Xb0_c_14: 0.0,
#   Xb0_c_2: 320.0,
#   Xb0_c_3: 360.0,
#   Xb0_c_4: 220.0,
#   Xb0_c_5: 0.0,
#   Xb0_c_6: 400.0,
#   Xb0_c_7: 0.0,
#   Xb0_c_8: 260.0,
#   Xb0_c_9: 0.0,
#   Xb0_rev_c_0: 360.0,
#   Xb0_rev_c_1: 200.0,
#   Xb0_rev_c_10: 0.0,
#   Xb0_rev_c_11: 320.0,
#   Xb0_rev_c_12: 360.0,
#   Xb0_rev_c_13: 0.0,
#   Xb0_rev_c_14: 0.0,
#   Xb0_rev_c_2: 320.0,
#   Xb0_rev_c_3: 360.0,
#   Xb0_rev_c_4: 220.0,
#   Xb0_rev_c_5: 0.0,
#   Xb0_rev_c_6: 400.0,
#   Xb0_rev_c_7: 0.0,
#   Xb0_rev_c_8: 260.0,
#   Xb0_rev_c_9: 0.0,
#   Xdb_0: 2800.0,
#   Yb_0: 1.0,
#   Yc_0: 1.0,
#   Yc_1: 1.0,
#   Yc_10: 0.0,
#   Yc_11: 1.0,
#   Yc_12: 1.0,
#   Yc_13: 0.0,
#   Yc_14: 0.0,
#   Yc_2: 1.0,
#   Yc_3: 1.0,
#   Yc_4: 1.0,
#   Yc_5: 0.0,
#   Yc_6: 1.0,
#   Yc_7: 0.0,
#   Yc_8: 1.0,
#   Yc_9: 0.0,
#   s2: 17088.0},
#  2: {Xab_0: 2800.0,
#   Xb0_c_0: 360.0,
#   Xb0_c_1: 200.0,
#   Xb0_c_10: 0.0,
#   Xb0_c_11: 320.0,
#   Xb0_c_12: 360.0,
#   Xb0_c_13: 0.0,
#   Xb0_c_14: 0.0,
#   Xb0_c_2: 320.0,
#   Xb0_c_3: 360.0,
#   Xb0_c_4: 220.0,
#   Xb0_c_5: 0.0,
#   Xb0_c_6: 400.0,
#   Xb0_c_7: 0.0,
#   Xb0_c_8: 260.0,
#   Xb0_c_9: 0.0,
#   Xb0_rev_c_0: 360.0,
#   Xb0_rev_c_1: 200.0,
#   Xb0_rev_c_10: 0.0,
#   Xb0_rev_c_11: 320.0,
#   Xb0_rev_c_12: 360.0,
#   Xb0_rev_c_13: 0.0,
#   Xb0_rev_c_14: 0.0,
#   Xb0_rev_c_2: 320.0,
#   Xb0_rev_c_3: 360.0,
#   Xb0_rev_c_4: 220.0,
#   Xb0_rev_c_5: 0.0,
#   Xb0_rev_c_6: 400.0,
#   Xb0_rev_c_7: 0.0,
#   Xb0_rev_c_8: 260.0,
#   Xb0_rev_c_9: 0.0,
#   Xdb_0: 2800.0,
#   Yb_0: 1.0,
#   Yc_0: 1.0,
#   Yc_1: 1.0,
#   Yc_10: 0.0,
#   Yc_11: 1.0,
#   Yc_12: 1.0,
#   Yc_13: 0.0,
#   Yc_14: 0.0,
#   Yc_2: 1.0,
#   Yc_3: 1.0,
#   Yc_4: 1.0,
#   Yc_5: 0.0,
#   Yc_6: 1.0,
#   Yc_7: 0.0,
#   Yc_8: 1.0,
#   Yc_9: 0.0,
#   s2: 5136.0},
#  3: {Xab_0: 2800.0,
#   Xb0_c_0: 360.0,
#   Xb0_c_1: 200.0,
#   Xb0_c_10: 0.0,
#   Xb0_c_11: 320.0,
#   Xb0_c_12: 360.0,
#   Xb0_c_13: 260.0,
#   Xb0_c_14: 0.0,
#   Xb0_c_2: 320.0,
#   Xb0_c_3: 360.0,
#   Xb0_c_4: 220.0,
#   Xb0_c_5: 0.0,
#   Xb0_c_6: 400.0,
#   Xb0_c_7: 0.0,
#   Xb0_c_8: 0.0,
#   Xb0_c_9: 0.0,
#   Xb0_rev_c_0: 360.0,
#   Xb0_rev_c_1: 200.0,
#   Xb0_rev_c_10: 0.0,
#   Xb0_rev_c_11: 320.0,
#   Xb0_rev_c_12: 360.0,
#   Xb0_rev_c_13: 260.0,
#   Xb0_rev_c_14: 0.0,
#   Xb0_rev_c_2: 320.0,
#   Xb0_rev_c_3: 360.0,
#   Xb0_rev_c_4: 220.0,
#   Xb0_rev_c_5: 0.0,
#   Xb0_rev_c_6: 400.0,
#   Xb0_rev_c_7: 0.0,
#   Xb0_rev_c_8: 0.0,
#   Xb0_rev_c_9: 0.0,
#   Xdb_0: 2800.0,
#   Yb_0: 1.0,
#   Yc_0: 1.0,
#   Yc_1: 1.0,
#   Yc_10: 0.0,
#   Yc_11: 1.0,
#   Yc_12: 1.0,
#   Yc_13: 1.0,
#   Yc_14: 0.0,
#   Yc_2: 1.0,
#   Yc_3: 1.0,
#   Yc_4: 1.0,
#   Yc_5: 0.0,
#   Yc_6: 1.0,
#   Yc_7: 0.0,
#   Yc_8: 0.0,
#   Yc_9: 0.0,
#   s2: 2544.0},
#  4: {Xab_0: 2800.0,
#   Xb0_c_0: 360.0,
#   Xb0_c_1: 200.0,
#   Xb0_c_10: 240.0,
#   Xb0_c_11: 0.0,
#   Xb0_c_12: 360.0,
#   Xb0_c_13: 0.0,
#   Xb0_c_14: 0.0,
#   Xb0_c_2: 320.0,
#   Xb0_c_3: 360.0,
#   Xb0_c_4: 220.0,
#   Xb0_c_5: 340.0,
#   Xb0_c_6: 400.0,
#   Xb0_c_7: 0.0,
#   Xb0_c_8: 0.0,
#   Xb0_c_9: 0.0,
#   Xb0_rev_c_0: 360.0,
#   Xb0_rev_c_1: 200.0,
#   Xb0_rev_c_10: 240.0,
#   Xb0_rev_c_11: 0.0,
#   Xb0_rev_c_12: 360.0,
#   Xb0_rev_c_13: 0.0,
#   Xb0_rev_c_14: 0.0,
#   Xb0_rev_c_2: 320.0,
#   Xb0_rev_c_3: 360.0,
#   Xb0_rev_c_4: 220.0,
#   Xb0_rev_c_5: 340.0,
#   Xb0_rev_c_6: 400.0,
#   Xb0_rev_c_7: 0.0,
#   Xb0_rev_c_8: 0.0,
#   Xb0_rev_c_9: 0.0,
#   Xdb_0: 2800.0,
#   Yb_0: 1.0,
#   Yc_0: 1.0,
#   Yc_1: 1.0,
#   Yc_10: 1.0,
#   Yc_11: 0.0,
#   Yc_12: 1.0,
#   Yc_13: 0.0,
#   Yc_14: 0.0,
#   Yc_2: 1.0,
#   Yc_3: 1.0,
#   Yc_4: 1.0,
#   Yc_5: 1.0,
#   Yc_6: 1.0,
#   Yc_7: 0.0,
#   Yc_8: 0.0,
#   Yc_9: 0.0,
#   s2: 2112.0},
#  5: {Xab_0: 2800.0,
#   Xb0_c_0: 360.0,
#   Xb0_c_1: 0.0,
#   Xb0_c_10: 0.0,
#   Xb0_c_11: 0.0,
#   Xb0_c_12: 360.0,
#   Xb0_c_13: 260.0,
#   Xb0_c_14: 140.0,
#   Xb0_c_2: 320.0,
#   Xb0_c_3: 360.0,
#   Xb0_c_4: 0.0,
#   Xb0_c_5: 340.0,
#   Xb0_c_6: 400.0,
#   Xb0_c_7: 0.0,
#   Xb0_c_8: 260.0,
#   Xb0_c_9: 0.0,
#   Xb0_rev_c_0: 360.0,
#   Xb0_rev_c_1: 0.0,
#   Xb0_rev_c_10: 0.0,
#   Xb0_rev_c_11: 0.0,
#   Xb0_rev_c_12: 360.0,
#   Xb0_rev_c_13: 260.0,
#   Xb0_rev_c_14: 140.0,
#   Xb0_rev_c_2: 320.0,
#   Xb0_rev_c_3: 360.0,
#   Xb0_rev_c_4: 0.0,
#   Xb0_rev_c_5: 340.0,
#   Xb0_rev_c_6: 400.0,
#   Xb0_rev_c_7: 0.0,
#   Xb0_rev_c_8: 260.0,
#   Xb0_rev_c_9: 0.0,
#   Xdb_0: 2800.0,
#   Yb_0: 1.0,
#   Yc_0: 1.0,
#   Yc_1: 0.0,
#   Yc_10: 0.0,
#   Yc_11: 0.0,
#   Yc_12: 1.0,
#   Yc_13: 1.0,
#   Yc_14: 1.0,
#   Yc_2: 1.0,
#   Yc_3: 1.0,
#   Yc_4: 0.0,
#   Yc_5: 1.0,
#   Yc_6: 1.0,
#   Yc_7: 0.0,
#   Yc_8: 1.0,
#   Yc_9: 0.0,
#   s2: 0.0}}

# %%
payoff
# Out:
# array([[1.23141920e+07, 1.32258312e+09],
#        [1.30002320e+07, 1.32252336e+09]])

# %%
# objective values at grid points for 1 year
lst
# Out:
# array([[1.23141920e+07, 1.32258312e+09],
#        [1.23213520e+07, 1.32255408e+09],
#        [1.23213520e+07, 1.32255408e+09],
#        [1.24397920e+07, 1.32254472e+09],
#        [1.25098720e+07, 1.32253320e+09],
#        [1.30002320e+07, 1.32252336e+09]])

# %%
plt.scatter(lst[:,0], lst[:,1])
# set axis lables
plt.xlabel("Z1")
plt.ylabel("Z2")
# set chart title
plt.title("Pareto-Optimal Solutions")
plt.show()

# %% [markdown]
# ## Multi criteria decision making (TOPSIS)

# %%
from topsis import topsis #Technique for Order of Preference by Similarity to Ideal Solution

# %%
w = [0.7,0.3]
I = [ 0, 0]
decision = topsis(lst, w, I)
decision.calc()
k = decision.optimum_choice
print('[cost,emission] : ',lst[k])
print('Flow characterstics : ')
print(key_intervals[k])
# Out:
# [cost,emission] :  [1.23141920e+07 1.32258312e+09]
# Flow characterstics :
# {Xab_0: 2800.0, Xb0_c_0: 360.0, Xb0_c_1: 200.0, Xb0_c_10: 240.0, Xb0_c_11: 320.0, Xb0_c_12: 360.0, Xb0_c_13: 0.0, Xb0_c_14: 0.0, Xb0_c_2: 0.0, Xb0_c_3: 360.0, Xb0_c_4: 220.0, Xb0_c_5: 340.0, Xb0_c_6: 400.0, Xb0_c_7: 0.0, Xb0_c_8: 0.0, Xb0_c_9: 0.0, Xb0_rev_c_0: 360.0, Xb0_rev_c_1: 200.0, Xb0_rev_c_10: 240.0, Xb0_rev_c_11: 320.0, Xb0_rev_c_12: 360.0, Xb0_rev_c_13: 0.0, Xb0_rev_c_14: 0.0, Xb0_rev_c_2: 0.0, Xb0_rev_c_3: 360.0, Xb0_rev_c_4: 220.0, Xb0_rev_c_5: 340.0, Xb0_rev_c_6: 400.0, Xb0_rev_c_7: 0.0, Xb0_rev_c_8: 0.0, Xb0_rev_c_9: 0.0, Xdb_0: 2800.0, Yb_0: 1.0, Yc_0: 1.0, Yc_1: 1.0, Yc_10: 1.0, Yc_11: 1.0, Yc_12: 1.0, Yc_13: 0.0, Yc_14: 0.0, Yc_2: 0.0, Yc_3: 1.0, Yc_4: 1.0, Yc_5: 1.0, Yc_6: 1.0, Yc_7: 0.0, Yc_8: 0.0, Yc_9: 0.0, s2: 0.0}
